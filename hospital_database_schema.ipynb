# %%
# =====================================
# 1. INSTALL & START MYSQL
# =====================================

# !apt-get update
# !apt-get install -y mysql-server
# !service mysql start
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,870 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:22 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,623 kB]
# Fetched 36.2 MB in 4s (8,146 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaio1 libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl
#   libfcgi-bin libfcgi-perl libfcgi0ldbl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2
#   libprotobuf-lite23 liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils
#   mysql-client-8.0 mysql-client-core-8.0 mysql-server-8.0
#   mysql-server-core-8.0
# Suggested packages:
#   libdata-dump-perl libipc-sharedcache-perl libbusiness-isbn-perl libwww-perl
#   mailx tinyca
# The following NEW packages will be installed:
#   libaio1 libcgi-fast-perl libcgi-pm-perl libclone-perl libencode-locale-perl
#   libfcgi-bin libfcgi-perl libfcgi0ldbl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-template-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl liblwp-mediatypes-perl libmecab2
#   libprotobuf-lite23 liburi-perl mecab-ipadic mecab-ipadic-utf8 mecab-utils
#   mysql-client-8.0 mysql-client-core-8.0 mysql-server mysql-server-8.0
#   mysql-server-core-8.0
# 0 upgraded, 26 newly installed, 0 to remove and 51 not upgraded.
# Need to get 29.7 MB of archives.
# After this operation, 243 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-client-core-8.0 amd64 8.0.44-0ubuntu0.22.04.2 [2,707 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-client-8.0 amd64 8.0.44-0ubuntu0.22.04.2 [22.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaio1 amd64 0.3.112-13build1 [7,176 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmecab2 amd64 0.996-14build9 [199 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf-lite23 amd64 3.12.4-1ubuntu7.22.04.4 [209 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server-core-8.0 amd64 8.0.44-0ubuntu0.22.04.2 [17.7 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server-8.0 amd64 8.0.44-0ubuntu0.22.04.2 [1,449 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcgi-pm-perl all 4.54-1 [188 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfcgi0ldbl amd64 2.4.2-2ubuntu0.1 [28.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfcgi-perl amd64 0.82+ds-1build1 [22.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcgi-fast-perl all 1:2.15-1 [10.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfcgi-bin amd64 2.4.2-2ubuntu0.1 [11.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-template-perl all 2.97-1.1 [59.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-utils amd64 0.996-14build9 [4,850 B]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic all 2.7.0-20070801+main-3 [6,718 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-3 [4,384 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mysql-server all 8.0.44-0ubuntu0.22.04.2 [9,460 B]
# Fetched 29.7 MB in 4s (7,329 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package mysql-client-core-8.0.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../00-mysql-client-core-8.0_8.0.44-0ubuntu0.22.04.2_amd64.deb ...
# Unpacking mysql-client-core-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Selecting previously unselected package mysql-client-8.0.
# Preparing to unpack .../01-mysql-client-8.0_8.0.44-0ubuntu0.22.04.2_amd64.deb ...
# Unpacking mysql-client-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Selecting previously unselected package libaio1:amd64.
# Preparing to unpack .../02-libaio1_0.3.112-13build1_amd64.deb ...
# Unpacking libaio1:amd64 (0.3.112-13build1) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-14build9_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-14build9) ...
# Selecting previously unselected package libprotobuf-lite23:amd64.
# Preparing to unpack .../04-libprotobuf-lite23_3.12.4-1ubuntu7.22.04.4_amd64.deb ...
# Unpacking libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.4) ...
# Selecting previously unselected package mysql-server-core-8.0.
# Preparing to unpack .../05-mysql-server-core-8.0_8.0.44-0ubuntu0.22.04.2_amd64.deb ...
# Unpacking mysql-server-core-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Selecting previously unselected package mysql-server-8.0.
# Preparing to unpack .../06-mysql-server-8.0_8.0.44-0ubuntu0.22.04.2_amd64.deb ...
# Unpacking mysql-server-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../07-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../08-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../09-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../10-libcgi-pm-perl_4.54-1_all.deb ...
# Unpacking libcgi-pm-perl (4.54-1) ...
# Selecting previously unselected package libfcgi0ldbl:amd64.
# Preparing to unpack .../11-libfcgi0ldbl_2.4.2-2ubuntu0.1_amd64.deb ...
# Unpacking libfcgi0ldbl:amd64 (2.4.2-2ubuntu0.1) ...
# Selecting previously unselected package libfcgi-perl:amd64.
# Preparing to unpack .../12-libfcgi-perl_0.82+ds-1build1_amd64.deb ...
# Unpacking libfcgi-perl:amd64 (0.82+ds-1build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../13-libcgi-fast-perl_1%3a2.15-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.15-1) ...
# Selecting previously unselected package libclone-perl.
# Preparing to unpack .../14-libclone-perl_0.45-1build3_amd64.deb ...
# Unpacking libclone-perl (0.45-1build3) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../15-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libfcgi-bin.
# Preparing to unpack .../16-libfcgi-bin_2.4.2-2ubuntu0.1_amd64.deb ...
# Unpacking libfcgi-bin (2.4.2-2ubuntu0.1) ...
# Selecting previously unselected package libhtml-template-perl.
# Preparing to unpack .../17-libhtml-template-perl_2.97-1.1_all.deb ...
# Unpacking libhtml-template-perl (2.97-1.1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../18-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../19-libio-html-perl_1.004-2_all.deb ...
# Unpacking libio-html-perl (1.004-2) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../20-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../21-libhttp-message-perl_6.36-1_all.deb ...
# Unpacking libhttp-message-perl (6.36-1) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../22-mecab-utils_0.996-14build9_amd64.deb ...
# Unpacking mecab-utils (0.996-14build9) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../23-mecab-ipadic_2.7.0-20070801+main-3_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-3) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../24-mecab-ipadic-utf8_2.7.0-20070801+main-3_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-3) ...
# Selecting previously unselected package mysql-server.
# Preparing to unpack .../25-mysql-server_8.0.44-0ubuntu0.22.04.2_all.deb ...
# Unpacking mysql-server (8.0.44-0ubuntu0.22.04.2) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libmecab2:amd64 (0.996-14build9) ...
# Setting up mysql-client-core-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Setting up libfcgi0ldbl:amd64 (2.4.2-2ubuntu0.1) ...
# Setting up libclone-perl (0.45-1build3) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libfcgi-bin (2.4.2-2ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1.1) ...
# Setting up libprotobuf-lite23:amd64 (3.12.4-1ubuntu7.22.04.4) ...
# Setting up mecab-utils (0.996-14build9) ...
# Setting up libio-html-perl (1.004-2) ...
# Setting up mysql-client-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Setting up libfcgi-perl:amd64 (0.82+ds-1build1) ...
# Setting up libaio1:amd64 (0.3.112-13build1) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-3) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mysql-server-core-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-3) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27328
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up mysql-server-8.0 (8.0.44-0ubuntu0.22.04.2) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# update-alternatives: using /etc/mysql/mysql.cnf to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Renaming removed key_buffer and myisam-recover options (if present)
# mysqld will log errors to /var/log/mysql/error.log
# mysqld is running as pid 1539
# Created symlink /etc/systemd/system/multi-user.target.wants/mysql.service → /lib/systemd/system/mysql.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libcgi-pm-perl (4.54-1) ...
# Setting up libhtml-template-perl (2.97-1.1) ...
# Setting up mysql-server (8.0.44-0ubuntu0.22.04.2) ...
# Setting up libcgi-fast-perl (1:2.15-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
#  * Starting MySQL database server mysqld
# su: warning: cannot change directory to /nonexistent: No such file or directory
#    ...done.

# %%
# =====================================
# 2. INSTALL MYSQL CONNECTOR
# =====================================

# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 60.2 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0

# %%
# =====================================
# 3. SET MYSQL ROOT PASSWORD
# =====================================

# !sudo mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'root';"

# %%
# =====================================
# 4. CONNECT PYTHON TO MYSQL
# =====================================

import mysql.connector
import random
from datetime import date, timedelta

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root"
)

cur = db.cursor()

# %%
# =====================================
# 5. CREATE DATABASE
# =====================================

cur.execute("create database if not exists schema_demo")
cur.execute("use schema_demo")

# %%
# =====================================
# 6. CREATE TABLE (TABLES + FIELDS + CONSTRAINTS)
# =====================================

cur.execute("""
create table student (
    student_id int primary key,
    name varchar(100) not null,
    gender varchar(10),
    dob date,
    phone varchar(15) unique,
    city varchar(50)
)
""")

# %%
# =====================================
# 7. INDIAN NAME DATA
# =====================================

male_names = [
    "Amit","Rahul","Arjun","Rohit","Vikas","Suresh","Ankit","Kunal","Ravi","Aditya"
]

female_names = [
    "Neha","Pooja","Anjali","Kavya","Riya","Priya","Sneha","Aarti","Nisha","Isha"
]

surnames = [
    "Sharma","Verma","Gupta","Singh","Patel","Kumar","Mehta","Reddy","Iyer","Das"
]

cities = [
    "Delhi","Mumbai","Bengaluru","Chennai","Kolkata",
    "Hyderabad","Pune","Jaipur","Indore","Lucknow"
]

# %%
# =====================================
# 8. FUNCTION TO GENERATE RANDOM DOB
# =====================================

def random_dob():
    start = date(1990, 1, 1)
    end = date(2010, 12, 31)
    return start + timedelta(days=random.randint(0, (end - start).days))

# %%
# =====================================
# 9. INSERT 1000 INDIAN STUDENT RECORDS
# =====================================

students = []

for i in range(1, 1001):
    gender = random.choice(["Male", "Female"])

    if gender == "Male":
        fname = random.choice(male_names)
    else:
        fname = random.choice(female_names)

    full_name = fname + " " + random.choice(surnames)
    phone = "9" + str(random.randint(100000000, 999999999))
    city = random.choice(cities)
    dob = random_dob()

    students.append((i, full_name, gender, dob, phone, city))

cur.executemany(
    "insert into student values (%s,%s,%s,%s,%s,%s)",
    students
)

db.commit()

# %%
# =====================================
# 10. DISPLAY ALL TABLES
# =====================================

print("TABLES IN DATABASE:")
cur.execute("show tables")
for t in cur:
    print(t)
# Out:
# TABLES IN DATABASE:
# ('student',)

# %%
# =====================================
# 11. DISPLAY STRUCTURE (FIELDS)
# =====================================

print("\nSTUDENT TABLE STRUCTURE:")
cur.execute("desc student")
for r in cur:
    print(r)
# Out:
# STUDENT TABLE STRUCTURE:
# ('student_id', 'int', 'NO', 'PRI', None, '')
# ('name', 'varchar(100)', 'NO', '', None, '')
# ('gender', 'varchar(10)', 'YES', '', None, '')
# ('dob', 'date', 'YES', '', None, '')
# ('phone', 'varchar(15)', 'YES', 'UNI', None, '')
# ('city', 'varchar(50)', 'YES', '', None, '')

# %%
# =====================================
# 12. DISPLAY ALL 1000 RECORDS
# =====================================

print("\nDISPLAYING 1000 INDIAN STUDENT RECORDS:\n")
cur.execute("select * from student")

for row in cur:
    print(row)


print("\n✅ 1000 Indian records displayed successfully")
# Out:
# DISPLAYING 1000 INDIAN STUDENT RECORDS:
#
# (1, 'Anjali Mehta', 'Female', datetime.date(2008, 3, 15), '9144072496', 'Indore')
# (2, 'Priya Verma', 'Female', datetime.date(1993, 3, 26), '9598775556', 'Chennai')
# (3, 'Sneha Gupta', 'Female', datetime.date(1991, 2, 11), '9650243139', 'Lucknow')
# (4, 'Aarti Kumar', 'Female', datetime.date(1998, 10, 18), '9706186124', 'Lucknow')
# (5, 'Sneha Das', 'Female', datetime.date(2001, 1, 22), '9470922138', 'Chennai')
# (6, 'Aditya Singh', 'Male', datetime.date(2007, 8, 24), '9839730146', 'Kolkata')
# (7, 'Ankit Patel', 'Male', datetime.date(2005, 9, 8), '9858431264', 'Indore')
# (8, 'Aarti Kumar', 'Female', datetime.date(2005, 9, 10), '9468566279', 'Mumbai')
# (9, 'Amit Gupta', 'Male', datetime.date(1997, 8, 17), '9177800893', 'Jaipur')
# (10, 'Sneha Sharma', 'Female', datetime.date(1998, 7, 26), '9224095566', 'Mumbai')
# (11, 'Nisha Das', 'Female', datetime.date(2009, 8, 14), '9550267577', 'Jaipur')
# (12, 'Sneha Singh', 'Female', datetime.date(2008, 11, 10), '9238280273', 'Chennai')
# (13, 'Neha Das', 'Female', datetime.date(1998, 8, 2), '9657293696', 'Bengaluru')
# (14, 'Amit Kumar', 'Male', datetime.date(2007, 4, 23), '9793394708', 'Indore')
# (15, 'Vikas Reddy', 'Male', datetime.date(2001, 6, 12), '9323626475', 'Pune')
# (16, 'Ankit Singh', 'Male', datetime.date(2003, 3, 28), '9973322356', 'Hyderabad')
# (17, 'Pooja Mehta', 'Female', datetime.date(1996, 3, 6), '9843834633', 'Pune')
# (18, 'Pooja Mehta', 'Female', datetime.date(2005, 9, 9), '9821014076', 'Indore')
# (19, 'Kavya Sharma', 'Female', datetime.date(2006, 2, 21), '9489196400', 'Lucknow')
# (20, 'Aditya Iyer', 'Male', datetime.date(2001, 1, 21), '9213750673', 'Bengaluru')
# (21, 'Vikas Sharma', 'Male', datetime.date(1994, 8, 24), '9120196892', 'Delhi')
# (22, 'Vikas Das', 'Male', datetime.date(2010, 10, 24), '9707079880', 'Mumbai')
# (23, 'Priya Mehta', 'Female', datetime.date(1991, 7, 3), '9394257570', 'Kolkata')
# (24, 'Pooja Sharma', 'Female', datetime.date(2007, 3, 7), '9684320600', 'Kolkata')
# (25, 'Rohit Sharma', 'Male', datetime.date(2010, 2, 24), '9347301708', 'Pune')
# (26, 'Anjali Mehta', 'Female', datetime.date(1998, 12, 15), '9286386774', 'Pune')
# (27, 'Aditya Reddy', 'Male', datetime.date(2006, 7, 6), '9821486566', 'Indore')
# (28, 'Pooja Das', 'Female', datetime.date(2004, 7, 23), '9101102821', 'Kolkata')
# (29, 'Suresh Das', 'Male', datetime.date(1996, 11, 21), '9241884054', 'Lucknow')
# (30, 'Riya Verma', 'Female', datetime.date(2009, 2, 26), '9726777032', 'Pune')
# (31, 'Ankit Iyer', 'Male', datetime.date(2004, 2, 4), '9302774240', 'Jaipur')
# (32, 'Amit Das', 'Male', datetime.date(1991, 5, 23), '9121598463', 'Chennai')
# (33, 'Rohit Verma', 'Male', datetime.date(1999, 12, 19), '9371944255', 'Jaipur')
# (34, 'Suresh Kumar', 'Male', datetime.date(2000, 6, 7), '9884886925', 'Hyderabad')
# (35, 'Ravi Verma', 'Male', datetime.date(1997, 4, 21), '9430840044', 'Lucknow')
# (36, 'Arjun Singh', 'Male', datetime.date(1994, 6, 26), '9635329404', 'Mumbai')
# (37, 'Suresh Kumar', 'Male', datetime.date(1991, 6, 3), '9898019277', 'Mumbai')
# (38, 'Riya Sharma', 'Female', datetime.date(2005, 9, 1), '9696394657', 'Lucknow')
# (39, 'Neha Singh', 'Female', datetime.date(2007, 12, 24), '9471934385', 'Chennai')
# (40, 'Nisha Verma', 'Female', datetime.date(1995, 3, 30), '9198358558', 'Bengaluru')
# (41, 'Kunal Patel', 'Male', datetime.date(2004, 3, 2), '9119980363', 'Mumbai')
# (42, 'Anjali Iyer', 'Female', datetime.date(1998, 2, 7), '9335967153', 'Pune')
# (43, 'Anjali Patel', 'Female', datetime.date(1996, 4, 27), '9447228696', 'Chennai')
# (44, 'Kunal Kumar', 'Male', datetime.date(1998, 1, 12), '9663785008', 'Jaipur')
# (45, 'Amit Mehta', 'Male', datetime.date(1997, 8, 26), '9915483959', 'Lucknow')
# (46, 'Priya Reddy', 'Female', datetime.date(1996, 9, 7), '9909369255', 'Hyderabad')
# (47, 'Ravi Mehta', 'Male', datetime.date(1999, 9, 1), '9982062228', 'Pune')
# (48, 'Amit Iyer', 'Male', datetime.date(1995, 4, 11), '9106149347', 'Chennai')
# (49, 'Kavya Das', 'Female', datetime.date(2000, 3, 17), '9638560814', 'Mumbai')
# (50, 'Aarti Reddy', 'Female', datetime.date(2006, 12, 13), '9974896488', 'Lucknow')
# (51, 'Nisha Kumar', 'Female', datetime.date(2010, 11, 3), '9760374665', 'Lucknow')
# (52, 'Aditya Iyer', 'Male', datetime.date(2005, 4, 7), '9244290032', 'Delhi')
# (53, 'Suresh Iyer', 'Male', datetime.date(1992, 2, 12), '9220632239', 'Lucknow')
# (54, 'Riya Kumar', 'Female', datetime.date(1990, 3, 30), '9665018994', 'Mumbai')
# (55, 'Isha Singh', 'Female', datetime.date(2010, 5, 9), '9517902838', 'Indore')
# (56, 'Priya Reddy', 'Female', datetime.date(2007, 7, 18), '9733327254', 'Lucknow')
# (57, 'Aditya Das', 'Male', datetime.date(1997, 4, 21), '9869557747', 'Indore')
# (58, 'Rahul Sharma', 'Male', datetime.date(2000, 2, 5), '9177538509', 'Indore')
# (59, 'Rohit Mehta', 'Male', datetime.date(1993, 7, 19), '9808127456', 'Jaipur')
# (60, 'Nisha Sharma', 'Female', datetime.date(2001, 7, 27), '9257091157', 'Kolkata')
# (61, 'Nisha Mehta', 'Female', datetime.date(2009, 7, 23), '9685247596', 'Jaipur')
# (62, 'Aarti Singh', 'Female', datetime.date(2003, 7, 23), '9675615554', 'Jaipur')
# (63, 'Neha Iyer', 'Female', datetime.date(1993, 3, 4), '9391785262', 'Lucknow')
# (64, 'Pooja Gupta', 'Female', datetime.date(2005, 1, 15), '9702319815', 'Chennai')
# (65, 'Nisha Mehta', 'Female', datetime.date(1993, 5, 9), '9241064817', 'Chennai')
# (66, 'Ravi Iyer', 'Male', datetime.date(1996, 2, 13), '9282669138', 'Bengaluru')
# (67, 'Riya Patel', 'Female', datetime.date(2005, 2, 13), '9226768125', 'Delhi')
# (68, 'Vikas Mehta', 'Male', datetime.date(2007, 7, 25), '9595749591', 'Kolkata')
# (69, 'Anjali Das', 'Female', datetime.date(2003, 8, 13), '9359197205', 'Kolkata')
# (70, 'Priya Verma', 'Female', datetime.date(2006, 5, 3), '9252569729', 'Jaipur')
# (71, 'Ankit Das', 'Male', datetime.date(1998, 5, 7), '9534798777', 'Delhi')
# (72, 'Rahul Iyer', 'Male', datetime.date(1999, 3, 5), '9800432919', 'Lucknow')
# (73, 'Amit Sharma', 'Male', datetime.date(2002, 3, 5), '9108430034', 'Pune')
# (74, 'Riya Das', 'Female', datetime.date(2001, 1, 25), '9438194160', 'Jaipur')
# (75, 'Anjali Reddy', 'Female', datetime.date(1995, 6, 3), '9467691492', 'Mumbai')
# (76, 'Isha Kumar', 'Female', datetime.date(2007, 4, 12), '9786073602', 'Mumbai')
# (77, 'Sneha Singh', 'Female', datetime.date(1995, 1, 27), '9363056990', 'Bengaluru')
# (78, 'Priya Mehta', 'Female', datetime.date(2005, 7, 12), '9356900511', 'Lucknow')
# (79, 'Suresh Verma', 'Male', datetime.date(2005, 10, 23), '9818996248', 'Pune')
# (80, 'Ravi Reddy', 'Male', datetime.date(1997, 4, 2), '9694295543', 'Indore')
# (81, 'Neha Sharma', 'Female', datetime.date(1993, 10, 21), '9441353685', 'Delhi')
# (82, 'Riya Mehta', 'Female', datetime.date(2004, 5, 21), '9926821120', 'Pune')
# (83, 'Isha Kumar', 'Female', datetime.date(2002, 5, 31), '9527617568', 'Delhi')
# (84, 'Rahul Verma', 'Male', datetime.date(2006, 3, 1), '9850170765', 'Delhi')
# (85, 'Rohit Patel', 'Male', datetime.date(2005, 2, 12), '9266339733', 'Bengaluru')
# (86, 'Pooja Reddy', 'Female', datetime.date(2000, 6, 14), '9472352613', 'Lucknow')
# (87, 'Rohit Gupta', 'Male', datetime.date(2002, 11, 19), '9938167930', 'Hyderabad')
# (88, 'Pooja Das', 'Female', datetime.date(2003, 8, 14), '9155874611', 'Kolkata')
# (89, 'Priya Das', 'Female', datetime.date(1995, 11, 13), '9225366403', 'Bengaluru')
# (90, 'Priya Reddy', 'Female', datetime.date(1994, 4, 20), '9570864386', 'Kolkata')
# (91, 'Amit Patel', 'Male', datetime.date(2003, 10, 17), '9141945594', 'Lucknow')
# (92, 'Rohit Patel', 'Male', datetime.date(1991, 1, 4), '9528430524', 'Lucknow')
# (93, 'Kunal Mehta', 'Male', datetime.date(1991, 6, 7), '9888536717', 'Pune')
# (94, 'Priya Patel', 'Female', datetime.date(2008, 9, 24), '9682806343', 'Hyderabad')
# (95, 'Amit Das', 'Male', datetime.date(2004, 9, 26), '9609267786', 'Indore')
# (96, 'Isha Iyer', 'Female', datetime.date(2001, 4, 9), '9442683110', 'Bengaluru')
# (97, 'Isha Reddy', 'Female', datetime.date(1999, 3, 14), '9139371658', 'Mumbai')
# (98, 'Anjali Das', 'Female', datetime.date(2008, 10, 1), '9383175490', 'Indore')
# (99, 'Anjali Singh', 'Female', datetime.date(2002, 3, 27), '9285160572', 'Lucknow')
# (100, 'Kunal Das', 'Male', datetime.date(2008, 11, 9), '9826819369', 'Bengaluru')
# (101, 'Nisha Verma', 'Female', datetime.date(2001, 7, 4), '9931008575', 'Chennai')
# (102, 'Ravi Gupta', 'Male', datetime.date(2000, 3, 8), '9449911338', 'Kolkata')
# (103, 'Vikas Verma', 'Male', datetime.date(2009, 10, 28), '9416876787', 'Bengaluru')
# (104, 'Suresh Mehta', 'Male', datetime.date(2000, 3, 30), '9120455364', 'Jaipur')
# (105, 'Vikas Iyer', 'Male', datetime.date(2001, 8, 6), '9581816334', 'Lucknow')
# (106, 'Isha Sharma', 'Female', datetime.date(2006, 10, 7), '9763359685', 'Hyderabad')
# (107, 'Arjun Verma', 'Male', datetime.date(2003, 12, 15), '9435260433', 'Delhi')
# (108, 'Neha Singh', 'Female', datetime.date(1990, 11, 10), '9440640508', 'Mumbai')
# (109, 'Rohit Mehta', 'Male', datetime.date(1999, 12, 9), '9659391796', 'Delhi')
# (110, 'Priya Patel', 'Female', datetime.date(2007, 6, 21), '9939220782', 'Indore')
# (111, 'Ankit Verma', 'Male', datetime.date(2004, 6, 13), '9838490243', 'Mumbai')
# (112, 'Ankit Verma', 'Male', datetime.date(2006, 7, 17), '9135365812', 'Lucknow')
# (113, 'Suresh Singh', 'Male', datetime.date(2010, 8, 24), '9171600518', 'Pune')
# (114, 'Aarti Iyer', 'Female', datetime.date(1999, 10, 13), '9496148215', 'Delhi')
# (115, 'Kunal Sharma', 'Male', datetime.date(2005, 7, 17), '9718289189', 'Lucknow')
# (116, 'Kavya Kumar', 'Female', datetime.date(2003, 7, 26), '9638651069', 'Chennai')
# (117, 'Pooja Patel', 'Female', datetime.date(1991, 2, 3), '9532382338', 'Kolkata')
# (118, 'Kunal Das', 'Male', datetime.date(2004, 4, 16), '9976350959', 'Kolkata')
# (119, 'Riya Patel', 'Female', datetime.date(2000, 10, 14), '9797395873', 'Pune')
# (120, 'Amit Das', 'Male', datetime.date(1991, 12, 17), '9563283475', 'Lucknow')
# (121, 'Sneha Das', 'Female', datetime.date(1994, 12, 20), '9157958972', 'Pune')
# (122, 'Isha Patel', 'Female', datetime.date(1991, 8, 29), '9747487249', 'Bengaluru')
# (123, 'Isha Mehta', 'Female', datetime.date(2009, 5, 24), '9302568981', 'Bengaluru')
# (124, 'Sneha Patel', 'Female', datetime.date(2006, 7, 30), '9109327842', 'Indore')
# (125, 'Ankit Reddy', 'Male', datetime.date(1992, 2, 1), '9790579921', 'Kolkata')
# (126, 'Pooja Patel', 'Female', datetime.date(1995, 11, 7), '9893356941', 'Bengaluru')
# (127, 'Pooja Kumar', 'Female', datetime.date(2005, 5, 12), '9379875433', 'Lucknow')
# (128, 'Suresh Mehta', 'Male', datetime.date(1996, 8, 27), '9393895501', 'Jaipur')
# (129, 'Kavya Kumar', 'Female', datetime.date(2009, 11, 8), '9774398808', 'Hyderabad')
# (130, 'Rahul Singh', 'Male', datetime.date(2003, 6, 29), '9958577654', 'Kolkata')
# (131, 'Rohit Verma', 'Male', datetime.date(1995, 6, 25), '9144555045', 'Bengaluru')
# (132, 'Vikas Patel', 'Male', datetime.date(2010, 10, 10), '9451650864', 'Lucknow')
# (133, 'Ravi Patel', 'Male', datetime.date(2008, 7, 17), '9975377498', 'Mumbai')
# (134, 'Ravi Mehta', 'Male', datetime.date(1995, 8, 27), '9411188283', 'Chennai')
# (135, 'Ankit Das', 'Male', datetime.date(2009, 9, 30), '9148922353', 'Bengaluru')
# (136, 'Aditya Singh', 'Male', datetime.date(1990, 6, 9), '9359436495', 'Delhi')
# (137, 'Aarti Iyer', 'Female', datetime.date(2002, 4, 22), '9551688254', 'Delhi')
# (138, 'Kunal Reddy', 'Male', datetime.date(1996, 10, 27), '9984088567', 'Pune')
# (139, 'Riya Iyer', 'Female', datetime.date(2009, 7, 1), '9974529432', 'Pune')
# (140, 'Kavya Singh', 'Female', datetime.date(2006, 2, 1), '9566785135', 'Hyderabad')
# (141, 'Isha Kumar', 'Female', datetime.date(1993, 2, 15), '9574434172', 'Indore')
# (142, 'Anjali Gupta', 'Female', datetime.date(2008, 5, 18), '9521259432', 'Delhi')
# (143, 'Aarti Singh', 'Female', datetime.date(1992, 8, 6), '9756992473', 'Indore')
# (144, 'Kavya Kumar', 'Female', datetime.date(1996, 7, 3), '9333387901', 'Mumbai')
# (145, 'Suresh Reddy', 'Male', datetime.date(2002, 3, 21), '9541386270', 'Lucknow')
# (146, 'Isha Das', 'Female', datetime.date(1995, 10, 20), '9506062194', 'Mumbai')
# (147, 'Aarti Kumar', 'Female', datetime.date(1998, 1, 5), '9604237381', 'Lucknow')
# (148, 'Ravi Singh', 'Male', datetime.date(2008, 5, 6), '9376121123', 'Jaipur')
# (149, 'Kunal Iyer', 'Male', datetime.date(1991, 6, 28), '9580430543', 'Lucknow')
# (150, 'Amit Mehta', 'Male', datetime.date(2010, 2, 1), '9244474728', 'Pune')
# (151, 'Amit Sharma', 'Male', datetime.date(2006, 7, 15), '9237770112', 'Indore')
# (152, 'Isha Kumar', 'Female', datetime.date(1999, 4, 25), '9231198144', 'Indore')
# (153, 'Nisha Iyer', 'Female', datetime.date(2005, 4, 14), '9955866785', 'Mumbai')
# (154, 'Isha Patel', 'Female', datetime.date(1991, 6, 20), '9614214885', 'Indore')
# (155, 'Suresh Verma', 'Male', datetime.date(1993, 11, 21), '9766327859', 'Bengaluru')
# (156, 'Vikas Mehta', 'Male', datetime.date(2004, 1, 30), '9968433834', 'Mumbai')
# (157, 'Isha Reddy', 'Female', datetime.date(1993, 5, 19), '9276122770', 'Bengaluru')
# (158, 'Anjali Patel', 'Female', datetime.date(2010, 4, 4), '9667553173', 'Pune')
# (159, 'Rahul Iyer', 'Male', datetime.date(1991, 1, 20), '9537215161', 'Pune')
# (160, 'Nisha Mehta', 'Female', datetime.date(2008, 6, 6), '9715671792', 'Bengaluru')
# (161, 'Vikas Kumar', 'Male', datetime.date(1996, 4, 27), '9278804756', 'Chennai')
# (162, 'Priya Verma', 'Female', datetime.date(2001, 6, 23), '9735675941', 'Kolkata')
# (163, 'Rohit Verma', 'Male', datetime.date(1995, 1, 13), '9971759406', 'Kolkata')
# (164, 'Anjali Singh', 'Female', datetime.date(2000, 7, 18), '9488209812', 'Jaipur')
# (165, 'Pooja Verma', 'Female', datetime.date(2006, 4, 26), '9636698267', 'Lucknow')
# (166, 'Rahul Reddy', 'Male', datetime.date(2009, 12, 5), '9988322067', 'Chennai')
# (167, 'Pooja Kumar', 'Female', datetime.date(2007, 11, 23), '9767070811', 'Delhi')
# (168, 'Aditya Das', 'Male', datetime.date(2001, 11, 9), '9126971062', 'Chennai')
# (169, 'Sneha Reddy', 'Female', datetime.date(2004, 10, 30), '9216071752', 'Indore')
# (170, 'Isha Reddy', 'Female', datetime.date(1991, 9, 3), '9975498545', 'Lucknow')
# (171, 'Aarti Kumar', 'Female', datetime.date(2002, 3, 8), '9355299837', 'Pune')
# (172, 'Kunal Iyer', 'Male', datetime.date(1991, 3, 3), '9454459974', 'Kolkata')
# (173, 'Sneha Kumar', 'Female', datetime.date(1997, 11, 8), '9221442035', 'Jaipur')
# (174, 'Amit Patel', 'Male', datetime.date(2008, 9, 19), '9345813854', 'Pune')
# (175, 'Nisha Gupta', 'Female', datetime.date(2003, 6, 7), '9143145997', 'Delhi')
# (176, 'Sneha Kumar', 'Female', datetime.date(1999, 3, 24), '9280646048', 'Indore')
# (177, 'Vikas Gupta', 'Male', datetime.date(2006, 6, 27), '9973910336', 'Chennai')
# (178, 'Nisha Das', 'Female', datetime.date(2008, 1, 11), '9749935854', 'Hyderabad')
# (179, 'Vikas Singh', 'Male', datetime.date(2004, 10, 7), '9152531457', 'Lucknow')
# (180, 'Arjun Sharma', 'Male', datetime.date(2000, 4, 15), '9213382992', 'Kolkata')
# (181, 'Priya Patel', 'Female', datetime.date(1996, 12, 9), '9205971047', 'Delhi')
# (182, 'Aarti Singh', 'Female', datetime.date(1990, 5, 2), '9534420909', 'Delhi')
# (183, 'Kavya Singh', 'Female', datetime.date(1993, 5, 10), '9163211704', 'Delhi')
# (184, 'Amit Iyer', 'Male', datetime.date(2001, 1, 16), '9720251220', 'Chennai')
# (185, 'Aarti Verma', 'Female', datetime.date(2005, 6, 25), '9373883802', 'Chennai')
# (186, 'Sneha Das', 'Female', datetime.date(1997, 7, 31), '9996902498', 'Hyderabad')
# (187, 'Ankit Patel', 'Male', datetime.date(1992, 8, 17), '9516691430', 'Pune')
# (188, 'Pooja Das', 'Female', datetime.date(1990, 1, 6), '9605731942', 'Kolkata')
# (189, 'Anjali Verma', 'Female', datetime.date(2009, 1, 28), '9340897251', 'Delhi')
# (190, 'Isha Kumar', 'Female', datetime.date(2006, 1, 17), '9566338103', 'Lucknow')
# (191, 'Isha Kumar', 'Female', datetime.date(2008, 6, 3), '9402700571', 'Lucknow')
# (192, 'Amit Gupta', 'Male', datetime.date(2004, 3, 12), '9522682380', 'Pune')
# (193, 'Amit Das', 'Male', datetime.date(2006, 5, 9), '9945742088', 'Delhi')
# (194, 'Pooja Sharma', 'Female', datetime.date(1994, 6, 11), '9451631251', 'Pune')
# (195, 'Isha Verma', 'Female', datetime.date(1990, 5, 20), '9122612205', 'Bengaluru')
# (196, 'Vikas Sharma', 'Male', datetime.date(2004, 8, 12), '9181964462', 'Chennai')
# (197, 'Anjali Das', 'Female', datetime.date(1994, 1, 2), '9448113505', 'Mumbai')
# (198, 'Arjun Singh', 'Male', datetime.date(2002, 12, 14), '9676517769', 'Hyderabad')
# (199, 'Rohit Singh', 'Male', datetime.date(2005, 1, 21), '9260234736', 'Chennai')
# (200, 'Neha Kumar', 'Female', datetime.date(1994, 1, 13), '9300178523', 'Jaipur')
# (201, 'Isha Gupta', 'Female', datetime.date(2009, 1, 10), '9800377808', 'Kolkata')
# (202, 'Priya Iyer', 'Female', datetime.date(2004, 12, 14), '9135688868', 'Pune')
# (203, 'Pooja Singh', 'Female', datetime.date(1994, 5, 27), '9555053242', 'Jaipur')
# (204, 'Aarti Sharma', 'Female', datetime.date(2003, 3, 11), '9803410785', 'Chennai')
# (205, 'Aditya Singh', 'Male', datetime.date(2006, 4, 30), '9850899058', 'Chennai')
# (206, 'Suresh Kumar', 'Male', datetime.date(2008, 7, 24), '9640778648', 'Mumbai')
# (207, 'Pooja Kumar', 'Female', datetime.date(2003, 12, 24), '9778410252', 'Hyderabad')
# (208, 'Neha Das', 'Female', datetime.date(2004, 1, 9), '9599963269', 'Hyderabad')
# (209, 'Vikas Das', 'Male', datetime.date(2010, 8, 17), '9735909527', 'Kolkata')
# (210, 'Amit Sharma', 'Male', datetime.date(2001, 6, 2), '9484137172', 'Jaipur')
# (211, 'Aarti Gupta', 'Female', datetime.date(1998, 2, 24), '9384644964', 'Hyderabad')
# (212, 'Sneha Das', 'Female', datetime.date(2008, 11, 25), '9697195584', 'Bengaluru')
# (213, 'Aditya Singh', 'Male', datetime.date(1998, 5, 19), '9158770382', 'Delhi')
# (214, 'Pooja Das', 'Female', datetime.date(2009, 7, 10), '9360852946', 'Indore')
# (215, 'Vikas Singh', 'Male', datetime.date(1997, 10, 23), '9389198135', 'Mumbai')
# (216, 'Pooja Das', 'Female', datetime.date(1993, 8, 4), '9460941467', 'Bengaluru')
# (217, 'Priya Mehta', 'Female', datetime.date(2004, 4, 26), '9694069313', 'Lucknow')
# (218, 'Ravi Reddy', 'Male', datetime.date(1997, 2, 24), '9666264454', 'Bengaluru')
# (219, 'Kavya Das', 'Female', datetime.date(2000, 4, 6), '9795907656', 'Pune')
# (220, 'Sneha Verma', 'Female', datetime.date(1992, 11, 29), '9501338689', 'Chennai')
# (221, 'Rahul Kumar', 'Male', datetime.date(2007, 2, 3), '9305221010', 'Kolkata')
# (222, 'Pooja Iyer', 'Female', datetime.date(2002, 5, 24), '9838456572', 'Chennai')
# (223, 'Isha Iyer', 'Female', datetime.date(1993, 5, 18), '9842053273', 'Hyderabad')
# (224, 'Arjun Mehta', 'Male', datetime.date(1995, 8, 9), '9769509570', 'Chennai')
# (225, 'Nisha Kumar', 'Female', datetime.date(2010, 3, 3), '9923287247', 'Delhi')
# (226, 'Rahul Verma', 'Male', datetime.date(1994, 1, 12), '9695878187', 'Pune')
# (227, 'Pooja Mehta', 'Female', datetime.date(1999, 1, 26), '9476553147', 'Delhi')
# (228, 'Neha Sharma', 'Female', datetime.date(2008, 3, 6), '9311510845', 'Hyderabad')
# (229, 'Anjali Singh', 'Female', datetime.date(2004, 10, 17), '9163238539', 'Lucknow')
# (230, 'Suresh Gupta', 'Male', datetime.date(1995, 12, 8), '9860420594', 'Indore')
# (231, 'Vikas Patel', 'Male', datetime.date(2000, 10, 4), '9225877396', 'Chennai')
# (232, 'Vikas Reddy', 'Male', datetime.date(2010, 3, 20), '9119949716', 'Indore')
# (233, 'Ankit Das', 'Male', datetime.date(2009, 1, 12), '9374013624', 'Pune')
# (234, 'Isha Singh', 'Female', datetime.date(2001, 11, 28), '9715715027', 'Chennai')
# (235, 'Riya Singh', 'Female', datetime.date(2007, 2, 21), '9564635375', 'Mumbai')
# (236, 'Pooja Das', 'Female', datetime.date(2002, 10, 7), '9371254889', 'Mumbai')
# (237, 'Amit Verma', 'Male', datetime.date(2009, 2, 24), '9908862995', 'Bengaluru')
# (238, 'Aarti Sharma', 'Female', datetime.date(2001, 11, 4), '9935683408', 'Indore')
# (239, 'Anjali Reddy', 'Female', datetime.date(2002, 5, 11), '9744430070', 'Delhi')
# (240, 'Sneha Patel', 'Female', datetime.date(2006, 3, 24), '9307521082', 'Indore')
# (241, 'Rahul Sharma', 'Male', datetime.date(1994, 10, 14), '9468625339', 'Mumbai')
# (242, 'Ankit Kumar', 'Male', datetime.date(1990, 3, 5), '9690527658', 'Delhi')
# (243, 'Pooja Gupta', 'Female', datetime.date(1992, 10, 1), '9608494741', 'Indore')
# (244, 'Neha Singh', 'Female', datetime.date(1997, 4, 23), '9452977770', 'Lucknow')
# (245, 'Aarti Patel', 'Female', datetime.date(1998, 7, 15), '9994127660', 'Bengaluru')
# (246, 'Anjali Sharma', 'Female', datetime.date(2008, 1, 14), '9842194808', 'Mumbai')
# (247, 'Nisha Sharma', 'Female', datetime.date(1991, 4, 16), '9694128339', 'Chennai')
# (248, 'Ravi Verma', 'Male', datetime.date(2003, 11, 3), '9169055825', 'Chennai')
# (249, 'Riya Sharma', 'Female', datetime.date(1991, 5, 13), '9559304493', 'Delhi')
# (250, 'Nisha Iyer', 'Female', datetime.date(2003, 7, 17), '9888538852', 'Delhi')
# (251, 'Riya Verma', 'Female', datetime.date(1998, 9, 22), '9715533251', 'Hyderabad')
# (252, 'Neha Singh', 'Female', datetime.date(2005, 4, 20), '9612327056', 'Indore')
# (253, 'Ravi Verma', 'Male', datetime.date(2007, 8, 16), '9851368673', 'Mumbai')
# (254, 'Aditya Verma', 'Male', datetime.date(1993, 4, 12), '9950633911', 'Mumbai')
# (255, 'Pooja Iyer', 'Female', datetime.date(1996, 1, 30), '9860394986', 'Indore')
# (256, 'Ravi Sharma', 'Male', datetime.date(2009, 12, 12), '9291330689', 'Lucknow')
# (257, 'Priya Verma', 'Female', datetime.date(1999, 7, 28), '9761097073', 'Jaipur')
# (258, 'Pooja Patel', 'Female', datetime.date(2007, 3, 6), '9386343954', 'Kolkata')
# (259, 'Sneha Kumar', 'Female', datetime.date(2002, 10, 14), '9853419107', 'Pune')
# (260, 'Anjali Reddy', 'Female', datetime.date(1994, 12, 19), '9482488624', 'Kolkata')
# (261, 'Sneha Patel', 'Female', datetime.date(1996, 3, 25), '9929665823', 'Chennai')
# (262, 'Kunal Kumar', 'Male', datetime.date(1993, 1, 17), '9174697976', 'Mumbai')
# (263, 'Rahul Gupta', 'Male', datetime.date(2010, 1, 15), '9679394429', 'Hyderabad')
# (264, 'Arjun Reddy', 'Male', datetime.date(2001, 1, 24), '9183638091', 'Delhi')
# (265, 'Priya Patel', 'Female', datetime.date(1999, 5, 31), '9476101616', 'Kolkata')
# (266, 'Suresh Mehta', 'Male', datetime.date(1996, 3, 29), '9226848253', 'Mumbai')
# (267, 'Anjali Mehta', 'Female', datetime.date(1998, 4, 9), '9830141728', 'Hyderabad')
# (268, 'Aditya Singh', 'Male', datetime.date(1991, 9, 8), '9539626331', 'Bengaluru')
# (269, 'Rohit Mehta', 'Male', datetime.date(1993, 10, 21), '9364841847', 'Lucknow')
# (270, 'Kavya Singh', 'Female', datetime.date(1998, 1, 5), '9532508368', 'Lucknow')
# (271, 'Riya Mehta', 'Female', datetime.date(1991, 4, 15), '9484305759', 'Mumbai')
# (272, 'Riya Gupta', 'Female', datetime.date(2006, 12, 30), '9130906728', 'Chennai')
# (273, 'Rohit Reddy', 'Male', datetime.date(1993, 12, 13), '9574839896', 'Jaipur')
# (274, 'Riya Singh', 'Female', datetime.date(2007, 5, 26), '9992201003', 'Jaipur')
# (275, 'Rohit Reddy', 'Male', datetime.date(1998, 11, 22), '9848152568', 'Bengaluru')
# (276, 'Isha Reddy', 'Female', datetime.date(2004, 4, 16), '9250254338', 'Kolkata')
# (277, 'Rohit Mehta', 'Male', datetime.date(2008, 2, 26), '9446162193', 'Indore')
# (278, 'Rahul Singh', 'Male', datetime.date(2009, 6, 10), '9793141727', 'Chennai')
# (279, 'Vikas Das', 'Male', datetime.date(1991, 2, 25), '9103957136', 'Mumbai')
# (280, 'Riya Das', 'Female', datetime.date(1996, 9, 14), '9823680486', 'Kolkata')
# (281, 'Nisha Patel', 'Female', datetime.date(1992, 4, 7), '9724263769', 'Pune')
# (282, 'Anjali Iyer', 'Female', datetime.date(2003, 4, 6), '9464557102', 'Mumbai')
# (283, 'Kunal Gupta', 'Male', datetime.date(2006, 11, 23), '9781260133', 'Mumbai')
# (284, 'Nisha Gupta', 'Female', datetime.date(2004, 6, 23), '9283267634', 'Bengaluru')
# (285, 'Rahul Das', 'Male', datetime.date(1994, 11, 22), '9907981689', 'Mumbai')
# (286, 'Sneha Mehta', 'Female', datetime.date(2006, 1, 16), '9145318958', 'Indore')
# (287, 'Kavya Iyer', 'Female', datetime.date(1995, 10, 20), '9983165000', 'Pune')
# (288, 'Sneha Gupta', 'Female', datetime.date(1998, 10, 6), '9315306211', 'Lucknow')
# (289, 'Aarti Patel', 'Female', datetime.date(2007, 8, 19), '9795812506', 'Mumbai')
# (290, 'Riya Sharma', 'Female', datetime.date(2006, 5, 22), '9174534469', 'Lucknow')
# (291, 'Kunal Singh', 'Male', datetime.date(1995, 10, 6), '9273876700', 'Bengaluru')
# (292, 'Pooja Verma', 'Female', datetime.date(2000, 10, 5), '9456886236', 'Indore')
# (293, 'Kavya Reddy', 'Female', datetime.date(2006, 11, 2), '9458746273', 'Bengaluru')
# (294, 'Pooja Iyer', 'Female', datetime.date(1999, 8, 28), '9218583300', 'Jaipur')
# (295, 'Kavya Gupta', 'Female', datetime.date(2008, 4, 4), '9704603899', 'Kolkata')
# (296, 'Suresh Reddy', 'Male', datetime.date(1998, 6, 25), '9198504232', 'Mumbai')
# (297, 'Amit Sharma', 'Male', datetime.date(2000, 1, 19), '9700709966', 'Mumbai')
# (298, 'Riya Patel', 'Female', datetime.date(2001, 6, 17), '9714139090', 'Mumbai')
# (299, 'Aditya Mehta', 'Male', datetime.date(1999, 2, 17), '9536191330', 'Mumbai')
# (300, 'Priya Gupta', 'Female', datetime.date(2008, 5, 3), '9578188453', 'Chennai')
# (301, 'Neha Iyer', 'Female', datetime.date(2005, 9, 21), '9394829759', 'Indore')
# (302, 'Sneha Mehta', 'Female', datetime.date(2002, 5, 26), '9541803658', 'Indore')
# (303, 'Rohit Kumar', 'Male', datetime.date(2003, 7, 12), '9263493221', 'Lucknow')
# (304, 'Riya Singh', 'Female', datetime.date(2005, 3, 30), '9682721449', 'Bengaluru')
# (305, 'Neha Mehta', 'Female', datetime.date(2008, 5, 21), '9494973739', 'Kolkata')
# (306, 'Aarti Singh', 'Female', datetime.date(1995, 6, 20), '9724558931', 'Bengaluru')
# (307, 'Kunal Verma', 'Male', datetime.date(1995, 12, 22), '9919820161', 'Kolkata')
# (308, 'Isha Patel', 'Female', datetime.date(2006, 5, 16), '9383846611', 'Indore')
# (309, 'Kunal Reddy', 'Male', datetime.date(1992, 7, 4), '9417279528', 'Delhi')
# (310, 'Pooja Reddy', 'Female', datetime.date(2005, 11, 11), '9402033472', 'Delhi')
# (311, 'Rahul Iyer', 'Male', datetime.date(1998, 7, 16), '9569371382', 'Bengaluru')
# (312, 'Nisha Sharma', 'Female', datetime.date(1999, 7, 29), '9285645474', 'Indore')
# (313, 'Aditya Patel', 'Male', datetime.date(2003, 9, 5), '9833641637', 'Pune')
# (314, 'Vikas Singh', 'Male', datetime.date(1990, 11, 27), '9974736770', 'Chennai')
# (315, 'Ankit Singh', 'Male', datetime.date(2007, 6, 12), '9735348667', 'Chennai')
# (316, 'Neha Sharma', 'Female', datetime.date(2004, 12, 19), '9617479671', 'Jaipur')
# (317, 'Neha Verma', 'Female', datetime.date(2003, 5, 4), '9725403947', 'Chennai')
# (318, 'Ravi Das', 'Male', datetime.date(2010, 3, 7), '9829167389', 'Indore')
# (319, 'Riya Singh', 'Female', datetime.date(1999, 6, 12), '9646738862', 'Delhi')
# (320, 'Nisha Gupta', 'Female', datetime.date(1990, 10, 24), '9751244894', 'Mumbai')
# (321, 'Kavya Reddy', 'Female', datetime.date(2004, 11, 20), '9746053041', 'Hyderabad')
# (322, 'Priya Iyer', 'Female', datetime.date(1997, 7, 2), '9362258347', 'Kolkata')
# (323, 'Aarti Patel', 'Female', datetime.date(2005, 6, 23), '9813846519', 'Chennai')
# (324, 'Amit Sharma', 'Male', datetime.date(1997, 9, 22), '9224396098', 'Lucknow')
# (325, 'Vikas Das', 'Male', datetime.date(2006, 4, 23), '9552937438', 'Mumbai')
# (326, 'Riya Das', 'Female', datetime.date(2005, 8, 7), '9778604083', 'Kolkata')
# (327, 'Vikas Verma', 'Male', datetime.date(2007, 8, 21), '9871616886', 'Kolkata')
# (328, 'Kunal Iyer', 'Male', datetime.date(1998, 10, 1), '9738198045', 'Kolkata')
# (329, 'Rohit Sharma', 'Male', datetime.date(2006, 4, 24), '9257652743', 'Kolkata')
# (330, 'Isha Singh', 'Female', datetime.date(2002, 10, 20), '9755802438', 'Bengaluru')
# (331, 'Pooja Sharma', 'Female', datetime.date(2001, 8, 30), '9270243262', 'Lucknow')
# (332, 'Rahul Singh', 'Male', datetime.date(2006, 10, 1), '9817725708', 'Chennai')
# (333, 'Riya Sharma', 'Female', datetime.date(1993, 2, 25), '9805278767', 'Delhi')
# (334, 'Riya Gupta', 'Female', datetime.date(1992, 9, 17), '9340128873', 'Mumbai')
# (335, 'Kunal Patel', 'Male', datetime.date(2002, 10, 4), '9586405031', 'Bengaluru')
# (336, 'Rohit Patel', 'Male', datetime.date(1993, 8, 19), '9796482979', 'Mumbai')
# (337, 'Neha Gupta', 'Female', datetime.date(2010, 7, 28), '9506041365', 'Bengaluru')
# (338, 'Kunal Reddy', 'Male', datetime.date(2006, 11, 27), '9706984682', 'Delhi')
# (339, 'Isha Sharma', 'Female', datetime.date(1997, 2, 13), '9227802641', 'Kolkata')
# (340, 'Isha Patel', 'Female', datetime.date(1993, 4, 4), '9278797423', 'Chennai')
# (341, 'Anjali Verma', 'Female', datetime.date(2005, 5, 10), '9526283123', 'Lucknow')
# (342, 'Aarti Reddy', 'Female', datetime.date(2007, 12, 29), '9973622685', 'Delhi')
# (343, 'Rohit Gupta', 'Male', datetime.date(1999, 2, 22), '9328948248', 'Pune')
# (344, 'Aarti Patel', 'Female', datetime.date(2008, 6, 28), '9561712146', 'Lucknow')
# (345, 'Priya Gupta', 'Female', datetime.date(1995, 5, 16), '9373647726', 'Indore')
# (346, 'Vikas Das', 'Male', datetime.date(1999, 3, 24), '9232979628', 'Mumbai')
# (347, 'Pooja Gupta', 'Female', datetime.date(2008, 7, 18), '9189192021', 'Pune')
# (348, 'Riya Verma', 'Female', datetime.date(1990, 2, 22), '9852100657', 'Chennai')
# (349, 'Kavya Das', 'Female', datetime.date(1990, 7, 16), '9698368145', 'Mumbai')
# (350, 'Neha Verma', 'Female', datetime.date(1998, 4, 17), '9852000684', 'Bengaluru')
# (351, 'Arjun Kumar', 'Male', datetime.date(2002, 9, 13), '9214397117', 'Hyderabad')
# (352, 'Suresh Das', 'Male', datetime.date(1992, 9, 18), '9682424655', 'Indore')
# (353, 'Pooja Kumar', 'Female', datetime.date(1990, 11, 28), '9743953051', 'Hyderabad')
# (354, 'Isha Reddy', 'Female', datetime.date(2006, 6, 26), '9518376345', 'Pune')
# (355, 'Rohit Das', 'Male', datetime.date(2001, 2, 5), '9727031659', 'Indore')
# (356, 'Isha Reddy', 'Female', datetime.date(2010, 9, 23), '9719396459', 'Delhi')
# (357, 'Riya Verma', 'Female', datetime.date(1998, 12, 24), '9639585466', 'Pune')
# (358, 'Rahul Gupta', 'Male', datetime.date(2004, 6, 28), '9943593645', 'Jaipur')
# (359, 'Rohit Iyer', 'Male', datetime.date(1991, 6, 8), '9306253131', 'Chennai')
# (360, 'Suresh Reddy', 'Male', datetime.date(1998, 1, 14), '9759543915', 'Jaipur')
# (361, 'Arjun Gupta', 'Male', datetime.date(1999, 3, 18), '9474309458', 'Bengaluru')
# (362, 'Rohit Sharma', 'Male', datetime.date(2000, 4, 23), '9874604749', 'Bengaluru')
# (363, 'Aditya Kumar', 'Male', datetime.date(2008, 2, 19), '9682262713', 'Hyderabad')
# (364, 'Rohit Iyer', 'Male', datetime.date(2002, 8, 30), '9416475636', 'Kolkata')
# (365, 'Rahul Das', 'Male', datetime.date(1999, 4, 7), '9734227594', 'Mumbai')
# (366, 'Nisha Patel', 'Female', datetime.date(2002, 7, 7), '9664091735', 'Mumbai')
# (367, 'Ankit Mehta', 'Male', datetime.date(2002, 10, 9), '9694752176', 'Mumbai')
# (368, 'Sneha Iyer', 'Female', datetime.date(1993, 12, 27), '9607622928', 'Lucknow')
# (369, 'Suresh Verma', 'Male', datetime.date(1999, 6, 20), '9574696750', 'Hyderabad')
# (370, 'Nisha Mehta', 'Female', datetime.date(2006, 7, 16), '9254116051', 'Lucknow')
# (371, 'Isha Gupta', 'Female', datetime.date(2007, 1, 24), '9905532325', 'Jaipur')
# (372, 'Rahul Kumar', 'Male', datetime.date(2009, 4, 17), '9118456292', 'Bengaluru')
# (373, 'Rohit Verma', 'Male', datetime.date(2002, 9, 25), '9396284132', 'Chennai')
# (374, 'Priya Patel', 'Female', datetime.date(1997, 6, 29), '9414508119', 'Kolkata')
# (375, 'Ankit Mehta', 'Male', datetime.date(1995, 7, 10), '9921543583', 'Mumbai')
# (376, 'Ravi Mehta', 'Male', datetime.date(2008, 12, 23), '9732082269', 'Lucknow')
# (377, 'Priya Gupta', 'Female', datetime.date(1996, 12, 22), '9700820188', 'Mumbai')
# (378, 'Vikas Kumar', 'Male', datetime.date(2002, 8, 24), '9217462032', 'Delhi')
# (379, 'Amit Mehta', 'Male', datetime.date(1992, 2, 29), '9893471361', 'Kolkata')
# (380, 'Ravi Mehta', 'Male', datetime.date(2002, 4, 22), '9986864786', 'Lucknow')
# (381, 'Kavya Das', 'Female', datetime.date(2009, 2, 11), '9481873403', 'Indore')
# (382, 'Amit Iyer', 'Male', datetime.date(1990, 11, 11), '9471383012', 'Indore')
# (383, 'Ankit Singh', 'Male', datetime.date(1995, 9, 27), '9535655181', 'Jaipur')
# (384, 'Anjali Sharma', 'Female', datetime.date(2007, 4, 27), '9712446149', 'Chennai')
# (385, 'Arjun Iyer', 'Male', datetime.date(2004, 4, 17), '9754516759', 'Lucknow')
# (386, 'Rohit Das', 'Male', datetime.date(2009, 4, 13), '9926587639', 'Chennai')
# (387, 'Anjali Mehta', 'Female', datetime.date(2008, 12, 13), '9999615077', 'Kolkata')
# (388, 'Suresh Kumar', 'Male', datetime.date(2009, 8, 26), '9660981592', 'Indore')
# (389, 'Anjali Gupta', 'Female', datetime.date(2000, 6, 14), '9205383611', 'Hyderabad')
# (390, 'Rohit Iyer', 'Male', datetime.date(1990, 9, 19), '9184524362', 'Chennai')
# (391, 'Priya Kumar', 'Female', datetime.date(2002, 7, 15), '9849285755', 'Indore')
# (392, 'Pooja Patel', 'Female', datetime.date(2002, 10, 16), '9474362822', 'Pune')
# (393, 'Rohit Singh', 'Male', datetime.date(2005, 12, 15), '9966814811', 'Indore')
# (394, 'Vikas Das', 'Male', datetime.date(1994, 2, 19), '9810576615', 'Delhi')
# (395, 'Priya Das', 'Female', datetime.date(1999, 1, 18), '9512979490', 'Delhi')
# (396, 'Vikas Kumar', 'Male', datetime.date(1999, 6, 9), '9810546608', 'Lucknow')
# (397, 'Kunal Singh', 'Male', datetime.date(1999, 6, 6), '9128079098', 'Indore')
# (398, 'Ravi Gupta', 'Male', datetime.date(2008, 5, 30), '9510614190', 'Lucknow')
# (399, 'Kunal Patel', 'Male', datetime.date(1991, 11, 19), '9182449167', 'Jaipur')
# (400, 'Priya Verma', 'Female', datetime.date(2009, 2, 25), '9845274234', 'Kolkata')
# (401, 'Anjali Patel', 'Female', datetime.date(2000, 11, 4), '9491289553', 'Chennai')
# (402, 'Sneha Kumar', 'Female', datetime.date(1998, 12, 5), '9788046057', 'Lucknow')
# (403, 'Arjun Singh', 'Male', datetime.date(1992, 12, 4), '9469079149', 'Mumbai')
# (404, 'Kunal Gupta', 'Male', datetime.date(1992, 8, 5), '9413957101', 'Lucknow')
# (405, 'Rohit Mehta', 'Male', datetime.date(1994, 4, 3), '9537951326', 'Bengaluru')
# (406, 'Kavya Sharma', 'Female', datetime.date(1996, 1, 23), '9697175441', 'Hyderabad')
# (407, 'Aditya Mehta', 'Male', datetime.date(2000, 5, 10), '9783055822', 'Hyderabad')
# (408, 'Sneha Verma', 'Female', datetime.date(2002, 9, 9), '9583488924', 'Jaipur')
# (409, 'Priya Gupta', 'Female', datetime.date(1996, 6, 30), '9496081538', 'Mumbai')
# (410, 'Arjun Iyer', 'Male', datetime.date(1991, 5, 5), '9262559586', 'Indore')
# (411, 'Priya Verma', 'Female', datetime.date(1995, 12, 7), '9320526045', 'Mumbai')
# (412, 'Neha Gupta', 'Female', datetime.date(1994, 3, 29), '9428739059', 'Mumbai')
# (413, 'Kavya Das', 'Female', datetime.date(1998, 4, 7), '9258376297', 'Delhi')
# (414, 'Vikas Verma', 'Male', datetime.date(2000, 5, 7), '9798253332', 'Hyderabad')
# (415, 'Anjali Singh', 'Female', datetime.date(1990, 12, 28), '9123106761', 'Pune')
# (416, 'Riya Patel', 'Female', datetime.date(2008, 7, 5), '9180920992', 'Indore')
# (417, 'Rahul Patel', 'Male', datetime.date(2004, 7, 11), '9935890707', 'Hyderabad')
# (418, 'Aarti Patel', 'Female', datetime.date(1992, 9, 11), '9877975148', 'Indore')
# (419, 'Amit Das', 'Male', datetime.date(1999, 10, 28), '9308070800', 'Lucknow')
# (420, 'Vikas Gupta', 'Male', datetime.date(2009, 12, 20), '9590050550', 'Mumbai')
# (421, 'Aarti Kumar', 'Female', datetime.date(2003, 2, 15), '9527152639', 'Indore')
# (422, 'Ankit Verma', 'Male', datetime.date(2003, 10, 4), '9223906266', 'Pune')
# (423, 'Anjali Iyer', 'Female', datetime.date(1990, 1, 11), '9189636103', 'Mumbai')
# (424, 'Pooja Iyer', 'Female', datetime.date(2000, 4, 2), '9183251985', 'Kolkata')
# (425, 'Kavya Mehta', 'Female', datetime.date(2008, 9, 30), '9772682325', 'Chennai')
# (426, 'Neha Reddy', 'Female', datetime.date(2002, 10, 18), '9257615927', 'Bengaluru')
# (427, 'Ankit Singh', 'Male', datetime.date(2000, 2, 7), '9256046523', 'Pune')
# (428, 'Sneha Patel', 'Female', datetime.date(1990, 1, 9), '9117127696', 'Lucknow')
# (429, 'Ravi Singh', 'Male', datetime.date(2008, 3, 4), '9903330711', 'Lucknow')
# (430, 'Aarti Verma', 'Female', datetime.date(2000, 12, 9), '9577325668', 'Delhi')
# (431, 'Amit Reddy', 'Male', datetime.date(1995, 5, 14), '9240502056', 'Kolkata')
# (432, 'Rohit Singh', 'Male', datetime.date(1999, 2, 19), '9207465647', 'Mumbai')
# (433, 'Ankit Reddy', 'Male', datetime.date(2001, 4, 19), '9327150313', 'Bengaluru')
# (434, 'Isha Mehta', 'Female', datetime.date(1993, 1, 11), '9874458394', 'Hyderabad')
# (435, 'Neha Das', 'Female', datetime.date(2009, 1, 29), '9593522595', 'Bengaluru')
# (436, 'Riya Singh', 'Female', datetime.date(2006, 11, 27), '9227303245', 'Jaipur')
# (437, 'Ravi Reddy', 'Male', datetime.date(1993, 10, 23), '9696199115', 'Chennai')
# (438, 'Nisha Reddy', 'Female', datetime.date(2009, 3, 31), '9501377028', 'Bengaluru')
# (439, 'Anjali Singh', 'Female', datetime.date(1995, 11, 8), '9370197760', 'Kolkata')
# (440, 'Kavya Mehta', 'Female', datetime.date(2003, 10, 30), '9576996365', 'Delhi')
# (441, 'Aarti Reddy', 'Female', datetime.date(1996, 9, 24), '9235545747', 'Pune')
# (442, 'Ravi Patel', 'Male', datetime.date(1991, 3, 18), '9287118904', 'Kolkata')
# (443, 'Vikas Iyer', 'Male', datetime.date(2004, 10, 5), '9282147188', 'Delhi')
# (444, 'Vikas Verma', 'Male', datetime.date(2000, 11, 12), '9277644681', 'Delhi')
# (445, 'Pooja Mehta', 'Female', datetime.date(1994, 3, 21), '9175890428', 'Indore')
# (446, 'Ravi Verma', 'Male', datetime.date(2007, 10, 30), '9289500973', 'Jaipur')
# (447, 'Sneha Reddy', 'Female', datetime.date(2010, 8, 24), '9662807485', 'Mumbai')
# (448, 'Rohit Verma', 'Male', datetime.date(2009, 3, 12), '9111232126', 'Indore')
# (449, 'Anjali Kumar', 'Female', datetime.date(2003, 4, 2), '9694103336', 'Lucknow')
# (450, 'Arjun Verma', 'Male', datetime.date(1996, 2, 3), '9540715774', 'Bengaluru')
# (451, 'Isha Reddy', 'Female', datetime.date(1996, 1, 9), '9405443281', 'Chennai')
# (452, 'Ankit Mehta', 'Male', datetime.date(1993, 9, 7), '9613380695', 'Delhi')
# (453, 'Sneha Gupta', 'Female', datetime.date(2000, 2, 29), '9166735230', 'Hyderabad')
# (454, 'Aditya Iyer', 'Male', datetime.date(2008, 1, 10), '9939998517', 'Delhi')
# (455, 'Aarti Mehta', 'Female', datetime.date(2000, 12, 12), '9682663700', 'Kolkata')
# (456, 'Rohit Verma', 'Male', datetime.date(2010, 4, 19), '9338007442', 'Delhi')
# (457, 'Ankit Kumar', 'Male', datetime.date(1993, 6, 28), '9268717576', 'Pune')
# (458, 'Aarti Patel', 'Female', datetime.date(2002, 9, 20), '9899517709', 'Hyderabad')
# (459, 'Kavya Gupta', 'Female', datetime.date(2003, 8, 23), '9555910007', 'Mumbai')
# (460, 'Rahul Singh', 'Male', datetime.date(2004, 8, 4), '9170017538', 'Hyderabad')
# (461, 'Aarti Sharma', 'Female', datetime.date(1994, 11, 10), '9137659117', 'Indore')
# (462, 'Anjali Sharma', 'Female', datetime.date(2008, 10, 28), '9626458924', 'Lucknow')
# (463, 'Suresh Reddy', 'Male', datetime.date(2006, 3, 25), '9272804453', 'Lucknow')
# (464, 'Amit Das', 'Male', datetime.date(1998, 11, 26), '9326004019', 'Lucknow')
# (465, 'Aarti Iyer', 'Female', datetime.date(1997, 10, 18), '9112267941', 'Lucknow')
# (466, 'Ravi Sharma', 'Male', datetime.date(2005, 11, 7), '9396995517', 'Kolkata')
# (467, 'Isha Mehta', 'Female', datetime.date(1993, 6, 13), '9822523186', 'Hyderabad')
# (468, 'Kavya Iyer', 'Female', datetime.date(1994, 3, 17), '9906645323', 'Chennai')
# (469, 'Anjali Iyer', 'Female', datetime.date(2007, 9, 4), '9554005862', 'Bengaluru')
# (470, 'Vikas Patel', 'Male', datetime.date(1999, 2, 7), '9394774930', 'Chennai')
# (471, 'Amit Sharma', 'Male', datetime.date(2007, 11, 12), '9271830582', 'Bengaluru')
# (472, 'Riya Das', 'Female', datetime.date(1997, 8, 6), '9114135751', 'Chennai')
# (473, 'Neha Mehta', 'Female', datetime.date(2005, 4, 14), '9405585692', 'Kolkata')
# (474, 'Rahul Das', 'Male', datetime.date(1992, 10, 21), '9964771883', 'Jaipur')
# (475, 'Kunal Reddy', 'Male', datetime.date(1991, 11, 7), '9803865341', 'Jaipur')
# (476, 'Amit Sharma', 'Male', datetime.date(1999, 2, 4), '9931869169', 'Kolkata')
# (477, 'Nisha Mehta', 'Female', datetime.date(1998, 3, 24), '9901249856', 'Kolkata')
# (478, 'Neha Sharma', 'Female', datetime.date(2002, 10, 29), '9710608946', 'Pune')
# (479, 'Rohit Sharma', 'Male', datetime.date(1998, 4, 12), '9526920725', 'Jaipur')
# (480, 'Vikas Iyer', 'Male', datetime.date(2001, 4, 24), '9384644310', 'Mumbai')
# (481, 'Rahul Sharma', 'Male', datetime.date(2008, 11, 9), '9219051266', 'Bengaluru')
# (482, 'Pooja Kumar', 'Female', datetime.date(1993, 7, 19), '9418085297', 'Delhi')
# (483, 'Pooja Mehta', 'Female', datetime.date(1993, 5, 27), '9217802783', 'Hyderabad')
# (484, 'Neha Verma', 'Female', datetime.date(2005, 8, 23), '9933337965', 'Mumbai')
# (485, 'Neha Patel', 'Female', datetime.date(2007, 4, 7), '9816531434', 'Delhi')
# (486, 'Ravi Iyer', 'Male', datetime.date(2010, 1, 4), '9976227344', 'Hyderabad')
# (487, 'Ankit Mehta', 'Male', datetime.date(1990, 4, 3), '9927669764', 'Lucknow')
# (488, 'Riya Patel', 'Female', datetime.date(2006, 9, 13), '9252258057', 'Indore')
# (489, 'Pooja Iyer', 'Female', datetime.date(2002, 6, 14), '9923842174', 'Delhi')
# (490, 'Sneha Sharma', 'Female', datetime.date(2009, 6, 15), '9860141739', 'Indore')
# (491, 'Isha Verma', 'Female', datetime.date(2008, 12, 23), '9198676338', 'Delhi')
# (492, 'Riya Patel', 'Female', datetime.date(1996, 2, 14), '9943079803', 'Bengaluru')
# (493, 'Isha Iyer', 'Female', datetime.date(2006, 3, 8), '9110206342', 'Bengaluru')
# (494, 'Ankit Iyer', 'Male', datetime.date(2008, 12, 9), '9622180226', 'Chennai')
# (495, 'Amit Das', 'Male', datetime.date(1990, 6, 19), '9610375619', 'Lucknow')
# (496, 'Ravi Patel', 'Male', datetime.date(1992, 8, 6), '9765014223', 'Hyderabad')
# (497, 'Isha Patel', 'Female', datetime.date(2004, 10, 8), '9665015920', 'Jaipur')
# (498, 'Sneha Das', 'Female', datetime.date(2009, 10, 10), '9225552466', 'Bengaluru')
# (499, 'Aditya Singh', 'Male', datetime.date(2009, 3, 19), '9321175006', 'Hyderabad')
# (500, 'Ankit Patel', 'Male', datetime.date(1990, 10, 1), '9754027152', 'Mumbai')
# (501, 'Kavya Mehta', 'Female', datetime.date(1991, 8, 9), '9939874526', 'Pune')
# (502, 'Rahul Verma', 'Male', datetime.date(1993, 3, 11), '9657081742', 'Lucknow')
# (503, 'Vikas Patel', 'Male', datetime.date(1991, 11, 15), '9330085348', 'Bengaluru')
# (504, 'Neha Sharma', 'Female', datetime.date(2004, 11, 15), '9578510982', 'Jaipur')
# (505, 'Nisha Patel', 'Female', datetime.date(1991, 12, 3), '9228503053', 'Bengaluru')
# (506, 'Ankit Reddy', 'Male', datetime.date(1997, 3, 12), '9629284736', 'Lucknow')
# (507, 'Neha Mehta', 'Female', datetime.date(1991, 2, 12), '9584819756', 'Jaipur')
# (508, 'Arjun Reddy', 'Male', datetime.date(2000, 4, 29), '9176162929', 'Mumbai')
# (509, 'Arjun Singh', 'Male', datetime.date(1992, 8, 22), '9786200271', 'Pune')
# (510, 'Ankit Patel', 'Male', datetime.date(1992, 10, 29), '9695167582', 'Bengaluru')
# (511, 'Amit Iyer', 'Male', datetime.date(1992, 9, 8), '9434721466', 'Delhi')
# (512, 'Nisha Iyer', 'Female', datetime.date(1995, 7, 12), '9821524815', 'Indore')
# (513, 'Riya Gupta', 'Female', datetime.date(1992, 8, 24), '9545388857', 'Chennai')
# (514, 'Rahul Sharma', 'Male', datetime.date(1996, 10, 18), '9462656547', 'Mumbai')
# (515, 'Isha Iyer', 'Female', datetime.date(2010, 2, 4), '9365463103', 'Chennai')
# (516, 'Riya Verma', 'Female', datetime.date(1997, 8, 9), '9145517619', 'Jaipur')
# (517, 'Nisha Kumar', 'Female', datetime.date(2006, 4, 4), '9389880413', 'Jaipur')
# (518, 'Neha Singh', 'Female', datetime.date(2001, 10, 11), '9568737521', 'Chennai')
# (519, 'Ravi Kumar', 'Male', datetime.date(1995, 4, 23), '9829468398', 'Bengaluru')
# (520, 'Nisha Mehta', 'Female', datetime.date(1996, 9, 21), '9272290227', 'Bengaluru')
# (521, 'Vikas Gupta', 'Male', datetime.date(1992, 7, 3), '9875649234', 'Chennai')
# (522, 'Aarti Sharma', 'Female', datetime.date(2007, 10, 18), '9272225096', 'Lucknow')
# (523, 'Rahul Patel', 'Male', datetime.date(1993, 4, 10), '9856867745', 'Lucknow')
# (524, 'Neha Kumar', 'Female', datetime.date(2000, 1, 22), '9928761110', 'Indore')
# (525, 'Arjun Gupta', 'Male', datetime.date(2003, 3, 9), '9825586866', 'Indore')
# (526, 'Aarti Mehta', 'Female', datetime.date(1995, 8, 2), '9468403397', 'Bengaluru')
# (527, 'Aarti Kumar', 'Female', datetime.date(1993, 12, 11), '9110777059', 'Mumbai')
# (528, 'Riya Patel', 'Female', datetime.date(1990, 6, 29), '9808434261', 'Chennai')
# (529, 'Nisha Patel', 'Female', datetime.date(1997, 8, 7), '9307005510', 'Delhi')
# (530, 'Rohit Singh', 'Male', datetime.date(2009, 9, 4), '9718800381', 'Mumbai')
# (531, 'Riya Gupta', 'Female', datetime.date(2003, 1, 9), '9615605840', 'Pune')
# (532, 'Anjali Singh', 'Female', datetime.date(2001, 4, 4), '9966044449', 'Hyderabad')
# (533, 'Isha Patel', 'Female', datetime.date(2003, 12, 14), '9511586086', 'Lucknow')
# (534, 'Amit Das', 'Male', datetime.date(1997, 10, 14), '9732294924', 'Hyderabad')
# (535, 'Aarti Iyer', 'Female', datetime.date(2000, 12, 9), '9173441095', 'Pune')
# (536, 'Sneha Verma', 'Female', datetime.date(1993, 8, 16), '9953542158', 'Chennai')
# (537, 'Kunal Iyer', 'Male', datetime.date(2003, 1, 26), '9661383910', 'Hyderabad')
# (538, 'Priya Mehta', 'Female', datetime.date(2000, 11, 11), '9703660010', 'Kolkata')
# (539, 'Vikas Kumar', 'Male', datetime.date(2001, 3, 20), '9187370695', 'Hyderabad')
# (540, 'Rohit Singh', 'Male', datetime.date(2006, 4, 21), '9859355018', 'Kolkata')
# (541, 'Kunal Kumar', 'Male', datetime.date(2000, 4, 7), '9548949857', 'Delhi')
# (542, 'Priya Reddy', 'Female', datetime.date(2005, 3, 4), '9442166642', 'Delhi')
# (543, 'Arjun Kumar', 'Male', datetime.date(1994, 5, 27), '9178512579', 'Pune')
# (544, 'Isha Reddy', 'Female', datetime.date(2001, 4, 2), '9687487446', 'Delhi')
# (545, 'Rohit Kumar', 'Male', datetime.date(1995, 9, 5), '9481951080', 'Hyderabad')
# (546, 'Ankit Patel', 'Male', datetime.date(1994, 7, 7), '9146473554', 'Mumbai')
# (547, 'Kunal Verma', 'Male', datetime.date(2001, 12, 21), '9793356601', 'Indore')
# (548, 'Priya Kumar', 'Female', datetime.date(1999, 3, 25), '9499649532', 'Kolkata')
# (549, 'Priya Das', 'Female', datetime.date(1992, 9, 8), '9280649307', 'Hyderabad')
# (550, 'Isha Iyer', 'Female', datetime.date(2005, 4, 5), '9670377959', 'Indore')
# (551, 'Kunal Mehta', 'Male', datetime.date(1997, 10, 23), '9636919084', 'Chennai')
# (552, 'Kunal Reddy', 'Male', datetime.date(2005, 9, 11), '9927398025', 'Chennai')
# (553, 'Rahul Verma', 'Male', datetime.date(1990, 7, 24), '9543414806', 'Pune')
# (554, 'Rahul Kumar', 'Male', datetime.date(1993, 2, 12), '9321003715', 'Bengaluru')
# (555, 'Priya Verma', 'Female', datetime.date(2003, 2, 9), '9819724235', 'Kolkata')
# (556, 'Ankit Singh', 'Male', datetime.date(2008, 3, 10), '9162417696', 'Indore')
# (557, 'Priya Reddy', 'Female', datetime.date(2010, 7, 11), '9700308814', 'Jaipur')
# (558, 'Aditya Gupta', 'Male', datetime.date(2006, 4, 21), '9378557347', 'Kolkata')
# (559, 'Amit Mehta', 'Male', datetime.date(1994, 10, 13), '9881706870', 'Pune')
# (560, 'Arjun Sharma', 'Male', datetime.date(2004, 8, 10), '9632507109', 'Delhi')
# (561, 'Isha Mehta', 'Female', datetime.date(2005, 7, 8), '9266471268', 'Indore')
# (562, 'Isha Iyer', 'Female', datetime.date(2005, 9, 8), '9799990296', 'Chennai')
# (563, 'Riya Kumar', 'Female', datetime.date(2002, 7, 11), '9864228804', 'Mumbai')
# (564, 'Suresh Kumar', 'Male', datetime.date(1994, 8, 8), '9571745308', 'Pune')
# (565, 'Rahul Sharma', 'Male', datetime.date(1993, 5, 26), '9803733249', 'Kolkata')
# (566, 'Arjun Sharma', 'Male', datetime.date(2005, 6, 4), '9167379479', 'Bengaluru')
# (567, 'Nisha Kumar', 'Female', datetime.date(1992, 5, 7), '9631639315', 'Kolkata')
# (568, 'Sneha Gupta', 'Female', datetime.date(1993, 12, 14), '9681682644', 'Kolkata')
# (569, 'Aditya Gupta', 'Male', datetime.date(1998, 1, 3), '9366177558', 'Pune')
# (570, 'Ravi Gupta', 'Male', datetime.date(2003, 4, 22), '9662965603', 'Pune')
# (571, 'Kunal Sharma', 'Male', datetime.date(2000, 5, 13), '9992019532', 'Mumbai')
# (572, 'Kunal Das', 'Male', datetime.date(1990, 1, 31), '9746444714', 'Chennai')
# (573, 'Priya Sharma', 'Female', datetime.date(1997, 2, 12), '9530241830', 'Delhi')
# (574, 'Aarti Iyer', 'Female', datetime.date(2010, 7, 26), '9964796065', 'Kolkata')
# (575, 'Suresh Verma', 'Male', datetime.date(2004, 8, 25), '9224899369', 'Lucknow')
# (576, 'Riya Patel', 'Female', datetime.date(2003, 3, 21), '9350501124', 'Pune')
# (577, 'Ankit Verma', 'Male', datetime.date(2003, 7, 16), '9630664762', 'Indore')
# (578, 'Ravi Patel', 'Male', datetime.date(2008, 4, 1), '9829133871', 'Indore')
# (579, 'Vikas Patel', 'Male', datetime.date(2000, 7, 29), '9468407455', 'Jaipur')
# (580, 'Arjun Gupta', 'Male', datetime.date(1996, 6, 15), '9871699289', 'Kolkata')
# (581, 'Aarti Gupta', 'Female', datetime.date(2010, 11, 6), '9385915183', 'Pune')
# (582, 'Kunal Iyer', 'Male', datetime.date(2004, 3, 3), '9642721450', 'Jaipur')
# (583, 'Aditya Kumar', 'Male', datetime.date(2007, 3, 30), '9825721426', 'Hyderabad')
# (584, 'Vikas Kumar', 'Male', datetime.date(2002, 1, 21), '9898718170', 'Indore')
# ...
# (807, 'Neha Iyer', 'Female', datetime.date(1992, 12, 3), '9818425582', 'Delhi')
# (808, 'Nisha Iyer', 'Female', datetime.date(2007, 11, 22), '9186899739', 'Indore')
# (809, 'Arjun Mehta', 'Male', datetime.date(1997, 7, 1), '9714326081', 'Jaipur')
# (810, 'Kunal Patel', 'Male', datetime.date(1991, 11, 2), '9550768295', 'Bengaluru')
# (811, 'Vikas Mehta', 'Male', datetime.date(1991, 3, 27), '9184471277', 'Hyderabad')
# (812, 'Ravi Verma', 'Male', datetime.date(2008, 10, 9), '9371211992', 'Jaipur')
# (813, 'Ankit Sharma', 'Male', datetime.date(2006, 3, 22), '9889715081', 'Delhi')
# (814, 'Ravi Sharma', 'Male', datetime.date(2002, 6, 16), '9973457069', 'Lucknow')
# (815, 'Aarti Sharma', 'Female', datetime.date(1994, 6, 22), '9472760171', 'Pune')
# (816, 'Ankit Das', 'Male', datetime.date(2000, 7, 1), '9516890471', 'Lucknow')
# (817, 'Nisha Reddy', 'Female', datetime.date(2005, 8, 26), '9311041054', 'Indore')
# (818, 'Aarti Sharma', 'Female', datetime.date(2010, 9, 8), '9335789587', 'Mumbai')
# (819, 'Ravi Kumar', 'Male', datetime.date(2007, 2, 28), '9497831014', 'Mumbai')
# (820, 'Rahul Kumar', 'Male', datetime.date(2002, 11, 14), '9268194415', 'Pune')
# (821, 'Isha Iyer', 'Female', datetime.date(1996, 8, 4), '9923405369', 'Lucknow')
# (822, 'Sneha Sharma', 'Female', datetime.date(2007, 6, 18), '9256578259', 'Kolkata')
# (823, 'Nisha Kumar', 'Female', datetime.date(1998, 10, 8), '9301629837', 'Pune')
# (824, 'Ravi Sharma', 'Male', datetime.date(1994, 2, 12), '9833914062', 'Chennai')
# (825, 'Priya Kumar', 'Female', datetime.date(2006, 4, 27), '9114228118', 'Indore')
# (826, 'Sneha Verma', 'Female', datetime.date(2005, 4, 7), '9492137912', 'Indore')
# (827, 'Rahul Patel', 'Male', datetime.date(2006, 11, 2), '9339150386', 'Kolkata')
# (828, 'Aarti Verma', 'Female', datetime.date(2005, 12, 15), '9117992238', 'Pune')
# (829, 'Aarti Iyer', 'Female', datetime.date(1998, 6, 30), '9759113006', 'Hyderabad')
# (830, 'Aditya Gupta', 'Male', datetime.date(2010, 1, 21), '9106473614', 'Lucknow')
# (831, 'Aditya Reddy', 'Male', datetime.date(2010, 4, 19), '9676564261', 'Delhi')
# (832, 'Suresh Sharma', 'Male', datetime.date(2005, 11, 28), '9448581670', 'Hyderabad')
# (833, 'Neha Das', 'Female', datetime.date(1998, 1, 2), '9410747989', 'Kolkata')
# (834, 'Priya Gupta', 'Female', datetime.date(1995, 4, 27), '9218581057', 'Kolkata')
# (835, 'Neha Mehta', 'Female', datetime.date(1993, 8, 13), '9165310002', 'Kolkata')
# (836, 'Arjun Patel', 'Male', datetime.date(1998, 5, 25), '9795566841', 'Kolkata')
# (837, 'Isha Kumar', 'Female', datetime.date(1992, 2, 1), '9670818332', 'Kolkata')
# (838, 'Arjun Kumar', 'Male', datetime.date(1997, 12, 8), '9782900679', 'Bengaluru')
# (839, 'Rahul Kumar', 'Male', datetime.date(1995, 11, 9), '9744068418', 'Delhi')
# (840, 'Ravi Gupta', 'Male', datetime.date(1997, 1, 30), '9306048585', 'Delhi')
# (841, 'Aditya Reddy', 'Male', datetime.date(1991, 12, 1), '9412651032', 'Kolkata')
# (842, 'Rohit Sharma', 'Male', datetime.date(1993, 1, 29), '9644918494', 'Indore')
# (843, 'Vikas Gupta', 'Male', datetime.date(2009, 10, 29), '9601218756', 'Hyderabad')
# (844, 'Neha Verma', 'Female', datetime.date(2000, 5, 27), '9273055912', 'Lucknow')
# (845, 'Arjun Kumar', 'Male', datetime.date(2006, 7, 18), '9722719539', 'Chennai')
# (846, 'Isha Verma', 'Female', datetime.date(2002, 5, 4), '9646472438', 'Kolkata')
# (847, 'Ravi Gupta', 'Male', datetime.date(1995, 4, 27), '9718460228', 'Pune')
# (848, 'Suresh Das', 'Male', datetime.date(1994, 8, 5), '9363747610', 'Mumbai')
# (849, 'Vikas Gupta', 'Male', datetime.date(2001, 7, 2), '9209163314', 'Lucknow')
# (850, 'Nisha Verma', 'Female', datetime.date(2005, 6, 14), '9723213961', 'Pune')
# (851, 'Nisha Reddy', 'Female', datetime.date(1990, 3, 11), '9416732820', 'Chennai')
# (852, 'Rohit Mehta', 'Male', datetime.date(2007, 3, 6), '9473406159', 'Hyderabad')
# (853, 'Rahul Gupta', 'Male', datetime.date(2006, 5, 19), '9877287830', 'Lucknow')
# (854, 'Rohit Singh', 'Male', datetime.date(1996, 7, 18), '9602211172', 'Bengaluru')
# (855, 'Priya Kumar', 'Female', datetime.date(2000, 8, 11), '9737020614', 'Pune')
# (856, 'Neha Verma', 'Female', datetime.date(1992, 8, 16), '9786913745', 'Lucknow')
# (857, 'Arjun Das', 'Male', datetime.date(1995, 7, 27), '9852562149', 'Mumbai')
# (858, 'Ankit Kumar', 'Male', datetime.date(1998, 3, 18), '9778292077', 'Indore')
# (859, 'Isha Das', 'Female', datetime.date(1995, 2, 20), '9116933808', 'Delhi')
# (860, 'Kavya Verma', 'Female', datetime.date(1997, 11, 3), '9489693487', 'Lucknow')
# (861, 'Amit Mehta', 'Male', datetime.date(2009, 12, 19), '9285543745', 'Mumbai')
# (862, 'Ravi Mehta', 'Male', datetime.date(1998, 5, 15), '9851301841', 'Delhi')
# (863, 'Ankit Patel', 'Male', datetime.date(2009, 9, 15), '9264334635', 'Bengaluru')
# (864, 'Ravi Sharma', 'Male', datetime.date(2003, 5, 16), '9489862446', 'Pune')
# (865, 'Priya Reddy', 'Female', datetime.date(2003, 6, 6), '9662979469', 'Jaipur')
# (866, 'Sneha Singh', 'Female', datetime.date(2010, 8, 18), '9658381575', 'Kolkata')
# (867, 'Sneha Iyer', 'Female', datetime.date(2004, 10, 9), '9678404355', 'Kolkata')
# (868, 'Ankit Reddy', 'Male', datetime.date(2010, 6, 5), '9937928449', 'Delhi')
# (869, 'Pooja Sharma', 'Female', datetime.date(2010, 9, 1), '9643621166', 'Bengaluru')
# (870, 'Neha Patel', 'Female', datetime.date(2007, 1, 11), '9620471951', 'Indore')
# (871, 'Priya Gupta', 'Female', datetime.date(1991, 8, 8), '9742636422', 'Chennai')
# (872, 'Kunal Patel', 'Male', datetime.date(1991, 5, 13), '9142595260', 'Chennai')
# (873, 'Kunal Kumar', 'Male', datetime.date(1998, 1, 11), '9388935486', 'Mumbai')
# (874, 'Arjun Das', 'Male', datetime.date(2008, 11, 21), '9155222016', 'Indore')
# (875, 'Amit Das', 'Male', datetime.date(1994, 12, 12), '9453130864', 'Lucknow')
# (876, 'Suresh Sharma', 'Male', datetime.date(2006, 12, 4), '9978948162', 'Delhi')
# (877, 'Ankit Gupta', 'Male', datetime.date(2007, 11, 7), '9905330980', 'Mumbai')
# (878, 'Aarti Kumar', 'Female', datetime.date(1992, 12, 13), '9908228256', 'Hyderabad')
# (879, 'Sneha Sharma', 'Female', datetime.date(1996, 12, 23), '9487086951', 'Jaipur')
# (880, 'Kunal Patel', 'Male', datetime.date(1990, 5, 16), '9769491983', 'Jaipur')
# (881, 'Ankit Verma', 'Male', datetime.date(1996, 6, 30), '9964813350', 'Indore')
# (882, 'Nisha Gupta', 'Female', datetime.date(2008, 3, 5), '9604449637', 'Delhi')
# (883, 'Pooja Das', 'Female', datetime.date(1994, 1, 3), '9226445312', 'Bengaluru')
# (884, 'Pooja Iyer', 'Female', datetime.date(2008, 4, 15), '9919316534', 'Lucknow')
# (885, 'Rohit Reddy', 'Male', datetime.date(2001, 3, 22), '9578115707', 'Indore')
# (886, 'Riya Mehta', 'Female', datetime.date(1995, 11, 6), '9162803065', 'Pune')
# (887, 'Suresh Iyer', 'Male', datetime.date(2000, 9, 21), '9350280304', 'Lucknow')
# (888, 'Aditya Gupta', 'Male', datetime.date(1999, 8, 12), '9385962743', 'Hyderabad')
# (889, 'Ravi Iyer', 'Male', datetime.date(2003, 5, 26), '9865596752', 'Delhi')
# (890, 'Arjun Das', 'Male', datetime.date(2004, 6, 22), '9429911117', 'Jaipur')
# (891, 'Rahul Verma', 'Male', datetime.date(1992, 6, 13), '9708692763', 'Chennai')
# (892, 'Suresh Das', 'Male', datetime.date(2007, 10, 23), '9581786067', 'Pune')
# (893, 'Rohit Das', 'Male', datetime.date(2010, 11, 5), '9961719387', 'Lucknow')
# (894, 'Kunal Kumar', 'Male', datetime.date(2002, 8, 5), '9966057335', 'Hyderabad')
# (895, 'Arjun Das', 'Male', datetime.date(1991, 9, 17), '9784617707', 'Bengaluru')
# (896, 'Nisha Singh', 'Female', datetime.date(2004, 4, 29), '9996132998', 'Jaipur')
# (897, 'Nisha Kumar', 'Female', datetime.date(1997, 4, 8), '9971888878', 'Mumbai')
# (898, 'Anjali Iyer', 'Female', datetime.date(1996, 10, 18), '9723899790', 'Hyderabad')
# (899, 'Ravi Das', 'Male', datetime.date(1990, 9, 15), '9667312037', 'Indore')
# (900, 'Ankit Patel', 'Male', datetime.date(2002, 10, 9), '9768846825', 'Kolkata')
# (901, 'Rohit Das', 'Male', datetime.date(2004, 7, 2), '9763858513', 'Bengaluru')
# (902, 'Rohit Sharma', 'Male', datetime.date(1992, 7, 18), '9861257218', 'Hyderabad')
# (903, 'Ankit Iyer', 'Male', datetime.date(1999, 8, 16), '9517782774', 'Lucknow')
# (904, 'Vikas Patel', 'Male', datetime.date(2003, 4, 9), '9718880272', 'Delhi')
# (905, 'Pooja Kumar', 'Female', datetime.date(1991, 12, 9), '9505577095', 'Indore')
# (906, 'Pooja Sharma', 'Female', datetime.date(2008, 5, 23), '9439859820', 'Lucknow')
# (907, 'Nisha Verma', 'Female', datetime.date(1998, 7, 5), '9996767201', 'Hyderabad')
# (908, 'Suresh Mehta', 'Male', datetime.date(2008, 7, 29), '9887678549', 'Jaipur')
# (909, 'Nisha Reddy', 'Female', datetime.date(2009, 12, 17), '9512521771', 'Indore')
# (910, 'Riya Kumar', 'Female', datetime.date(2004, 12, 18), '9289828756', 'Jaipur')
# (911, 'Riya Gupta', 'Female', datetime.date(2001, 6, 20), '9571118054', 'Jaipur')
# (912, 'Aarti Das', 'Female', datetime.date(1996, 5, 28), '9171492654', 'Jaipur')
# (913, 'Arjun Reddy', 'Male', datetime.date(1991, 11, 25), '9686120657', 'Indore')
# (914, 'Kunal Reddy', 'Male', datetime.date(1994, 3, 13), '9347007674', 'Hyderabad')
# (915, 'Rohit Reddy', 'Male', datetime.date(2005, 12, 5), '9995970904', 'Jaipur')
# (916, 'Arjun Mehta', 'Male', datetime.date(2010, 9, 20), '9127703496', 'Kolkata')
# (917, 'Arjun Kumar', 'Male', datetime.date(1996, 6, 20), '9924181731', 'Hyderabad')
# (918, 'Pooja Das', 'Female', datetime.date(2002, 9, 2), '9803274484', 'Kolkata')
# (919, 'Isha Verma', 'Female', datetime.date(1995, 12, 16), '9710037247', 'Chennai')
# (920, 'Pooja Das', 'Female', datetime.date(2009, 7, 13), '9664085411', 'Hyderabad')
# (921, 'Rahul Das', 'Male', datetime.date(1994, 1, 24), '9505712256', 'Delhi')
# (922, 'Isha Mehta', 'Female', datetime.date(2002, 3, 26), '9691879531', 'Delhi')
# (923, 'Aditya Sharma', 'Male', datetime.date(1990, 8, 7), '9647345904', 'Lucknow')
# (924, 'Rohit Das', 'Male', datetime.date(2006, 7, 24), '9366216583', 'Hyderabad')
# (925, 'Vikas Singh', 'Male', datetime.date(2002, 12, 23), '9633598757', 'Bengaluru')
# (926, 'Ravi Kumar', 'Male', datetime.date(1995, 8, 26), '9897684548', 'Delhi')
# (927, 'Suresh Gupta', 'Male', datetime.date(2007, 6, 29), '9609976914', 'Indore')
# (928, 'Priya Das', 'Female', datetime.date(2003, 2, 9), '9202745519', 'Pune')
# (929, 'Pooja Iyer', 'Female', datetime.date(2010, 9, 20), '9811689495', 'Chennai')
# (930, 'Ankit Verma', 'Male', datetime.date(1999, 3, 14), '9915592876', 'Hyderabad')
# (931, 'Aditya Singh', 'Male', datetime.date(2002, 11, 1), '9757167421', 'Hyderabad')
# (932, 'Aarti Sharma', 'Female', datetime.date(2009, 6, 15), '9453635916', 'Pune')
# (933, 'Suresh Reddy', 'Male', datetime.date(2009, 8, 1), '9865195603', 'Delhi')
# (934, 'Ravi Iyer', 'Male', datetime.date(1994, 5, 29), '9402217289', 'Indore')
# (935, 'Kunal Das', 'Male', datetime.date(2002, 12, 9), '9872674377', 'Delhi')
# (936, 'Rohit Iyer', 'Male', datetime.date(2002, 9, 5), '9900424028', 'Hyderabad')
# (937, 'Kunal Kumar', 'Male', datetime.date(1995, 1, 30), '9923732031', 'Kolkata')
# (938, 'Riya Reddy', 'Female', datetime.date(2007, 4, 22), '9768097266', 'Kolkata')
# (939, 'Isha Iyer', 'Female', datetime.date(1993, 10, 10), '9339916098', 'Jaipur')
# (940, 'Kunal Gupta', 'Male', datetime.date(2010, 1, 26), '9893299783', 'Kolkata')
# (941, 'Amit Mehta', 'Male', datetime.date(1995, 6, 18), '9655552149', 'Delhi')
# (942, 'Kunal Iyer', 'Male', datetime.date(2005, 5, 27), '9746321311', 'Pune')
# (943, 'Riya Mehta', 'Female', datetime.date(2007, 8, 18), '9491179237', 'Indore')
# (944, 'Aarti Kumar', 'Female', datetime.date(2007, 11, 12), '9469269156', 'Indore')
# (945, 'Aarti Iyer', 'Female', datetime.date(2004, 4, 19), '9289217443', 'Jaipur')
# (946, 'Ravi Kumar', 'Male', datetime.date(1995, 9, 26), '9406252556', 'Kolkata')
# (947, 'Vikas Sharma', 'Male', datetime.date(1992, 12, 3), '9250208870', 'Kolkata')
# (948, 'Nisha Gupta', 'Female', datetime.date(1990, 10, 5), '9314459773', 'Hyderabad')
# (949, 'Rohit Das', 'Male', datetime.date(2010, 11, 23), '9426539507', 'Indore')
# (950, 'Rohit Kumar', 'Male', datetime.date(1999, 7, 28), '9356618459', 'Pune')
# (951, 'Sneha Singh', 'Female', datetime.date(2006, 4, 26), '9444282994', 'Lucknow')
# (952, 'Suresh Iyer', 'Male', datetime.date(1999, 10, 5), '9270827932', 'Kolkata')
# (953, 'Ravi Reddy', 'Male', datetime.date(1996, 5, 14), '9808211515', 'Jaipur')
# (954, 'Amit Mehta', 'Male', datetime.date(1994, 9, 2), '9602697795', 'Hyderabad')
# (955, 'Anjali Mehta', 'Female', datetime.date(2000, 9, 10), '9924202666', 'Chennai')
# (956, 'Ravi Singh', 'Male', datetime.date(1994, 3, 10), '9788806579', 'Mumbai')
# (957, 'Nisha Singh', 'Female', datetime.date(2004, 11, 22), '9103626042', 'Delhi')
# (958, 'Aditya Verma', 'Male', datetime.date(1994, 7, 8), '9478346105', 'Hyderabad')
# (959, 'Aditya Iyer', 'Male', datetime.date(1990, 5, 6), '9658900654', 'Lucknow')
# (960, 'Nisha Kumar', 'Female', datetime.date(2001, 8, 2), '9941154795', 'Chennai')
# (961, 'Priya Verma', 'Female', datetime.date(2002, 9, 25), '9848225594', 'Pune')
# (962, 'Rahul Singh', 'Male', datetime.date(2008, 10, 1), '9334100930', 'Chennai')
# (963, 'Suresh Verma', 'Male', datetime.date(2004, 1, 18), '9463815197', 'Bengaluru')
# (964, 'Nisha Sharma', 'Female', datetime.date(2006, 11, 10), '9165888160', 'Mumbai')
# (965, 'Aditya Iyer', 'Male', datetime.date(1995, 10, 29), '9690467630', 'Mumbai')
# (966, 'Kavya Gupta', 'Female', datetime.date(2006, 4, 27), '9567095669', 'Mumbai')
# (967, 'Nisha Iyer', 'Female', datetime.date(2010, 7, 10), '9420854142', 'Lucknow')
# (968, 'Kavya Das', 'Female', datetime.date(2003, 7, 12), '9804821669', 'Indore')
# (969, 'Ankit Reddy', 'Male', datetime.date(2000, 10, 11), '9472351844', 'Bengaluru')
# (970, 'Amit Reddy', 'Male', datetime.date(2006, 5, 24), '9978580859', 'Jaipur')
# (971, 'Aarti Reddy', 'Female', datetime.date(1992, 7, 11), '9968039175', 'Bengaluru')
# (972, 'Isha Das', 'Female', datetime.date(1993, 5, 2), '9351857102', 'Jaipur')
# (973, 'Aarti Gupta', 'Female', datetime.date(2010, 3, 13), '9228610694', 'Hyderabad')
# (974, 'Aarti Iyer', 'Female', datetime.date(2000, 8, 16), '9181223429', 'Jaipur')
# (975, 'Aditya Verma', 'Male', datetime.date(1994, 2, 10), '9444118781', 'Hyderabad')
# (976, 'Ankit Das', 'Male', datetime.date(2002, 12, 26), '9307844600', 'Chennai')
# (977, 'Aarti Sharma', 'Female', datetime.date(2003, 10, 20), '9783647462', 'Kolkata')
# (978, 'Ankit Iyer', 'Male', datetime.date(2001, 5, 19), '9150672000', 'Lucknow')
# (979, 'Kunal Iyer', 'Male', datetime.date(2010, 12, 11), '9982922995', 'Hyderabad')
# (980, 'Amit Patel', 'Male', datetime.date(1993, 10, 27), '9774090772', 'Delhi')
# (981, 'Isha Patel', 'Female', datetime.date(2008, 4, 21), '9933527546', 'Indore')
# (982, 'Ravi Iyer', 'Male', datetime.date(2006, 6, 3), '9959448935', 'Kolkata')
# (983, 'Rahul Singh', 'Male', datetime.date(2005, 8, 29), '9479986266', 'Bengaluru')
# (984, 'Riya Singh', 'Female', datetime.date(1991, 8, 21), '9573877931', 'Mumbai')
# (985, 'Kavya Reddy', 'Female', datetime.date(2003, 3, 29), '9899745409', 'Kolkata')
# (986, 'Kavya Singh', 'Female', datetime.date(1997, 11, 22), '9205859557', 'Indore')
# (987, 'Ankit Kumar', 'Male', datetime.date(1990, 5, 30), '9532013121', 'Delhi')
# (988, 'Aditya Reddy', 'Male', datetime.date(1992, 10, 12), '9672640794', 'Pune')
# (989, 'Nisha Sharma', 'Female', datetime.date(1998, 11, 15), '9440365712', 'Lucknow')
# (990, 'Rahul Das', 'Male', datetime.date(2006, 7, 16), '9579469150', 'Mumbai')
# (991, 'Aditya Mehta', 'Male', datetime.date(1998, 2, 26), '9848362931', 'Kolkata')
# (992, 'Kavya Kumar', 'Female', datetime.date(2007, 8, 29), '9547929104', 'Bengaluru')
# (993, 'Suresh Gupta', 'Male', datetime.date(1990, 9, 2), '9548641721', 'Pune')
# (994, 'Suresh Das', 'Male', datetime.date(1998, 9, 23), '9364404646', 'Jaipur')
# (995, 'Anjali Das', 'Female', datetime.date(1998, 2, 21), '9509867867', 'Bengaluru')
# (996, 'Sneha Singh', 'Female', datetime.date(2001, 10, 10), '9141769629', 'Kolkata')
# (997, 'Priya Singh', 'Female', datetime.date(2000, 8, 27), '9913217444', 'Hyderabad')
# (998, 'Isha Gupta', 'Female', datetime.date(1993, 2, 15), '9700415770', 'Kolkata')
# (999, 'Arjun Mehta', 'Male', datetime.date(1990, 11, 22), '9382217429', 'Kolkata')
# (1000, 'Pooja Mehta', 'Female', datetime.date(2001, 4, 15), '9988155057', 'Chennai')
#
# ✅ 1000 Indian records displayed successfully

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="schema_demo"
)

cur = db.cursor()

cur.execute("select * from student limit 1000")

for row in cur:
    print(row)
# Out:
# (1, 'Anjali Mehta', 'Female', datetime.date(2008, 3, 15), '9144072496', 'Indore')
# (2, 'Priya Verma', 'Female', datetime.date(1993, 3, 26), '9598775556', 'Chennai')
# (3, 'Sneha Gupta', 'Female', datetime.date(1991, 2, 11), '9650243139', 'Lucknow')
# (4, 'Aarti Kumar', 'Female', datetime.date(1998, 10, 18), '9706186124', 'Lucknow')
# (5, 'Sneha Das', 'Female', datetime.date(2001, 1, 22), '9470922138', 'Chennai')
# (6, 'Aditya Singh', 'Male', datetime.date(2007, 8, 24), '9839730146', 'Kolkata')
# (7, 'Ankit Patel', 'Male', datetime.date(2005, 9, 8), '9858431264', 'Indore')
# (8, 'Aarti Kumar', 'Female', datetime.date(2005, 9, 10), '9468566279', 'Mumbai')
# (9, 'Amit Gupta', 'Male', datetime.date(1997, 8, 17), '9177800893', 'Jaipur')
# (10, 'Sneha Sharma', 'Female', datetime.date(1998, 7, 26), '9224095566', 'Mumbai')
# (11, 'Nisha Das', 'Female', datetime.date(2009, 8, 14), '9550267577', 'Jaipur')
# (12, 'Sneha Singh', 'Female', datetime.date(2008, 11, 10), '9238280273', 'Chennai')
# (13, 'Neha Das', 'Female', datetime.date(1998, 8, 2), '9657293696', 'Bengaluru')
# (14, 'Amit Kumar', 'Male', datetime.date(2007, 4, 23), '9793394708', 'Indore')
# (15, 'Vikas Reddy', 'Male', datetime.date(2001, 6, 12), '9323626475', 'Pune')
# (16, 'Ankit Singh', 'Male', datetime.date(2003, 3, 28), '9973322356', 'Hyderabad')
# (17, 'Pooja Mehta', 'Female', datetime.date(1996, 3, 6), '9843834633', 'Pune')
# (18, 'Pooja Mehta', 'Female', datetime.date(2005, 9, 9), '9821014076', 'Indore')
# (19, 'Kavya Sharma', 'Female', datetime.date(2006, 2, 21), '9489196400', 'Lucknow')
# (20, 'Aditya Iyer', 'Male', datetime.date(2001, 1, 21), '9213750673', 'Bengaluru')
# (21, 'Vikas Sharma', 'Male', datetime.date(1994, 8, 24), '9120196892', 'Delhi')
# (22, 'Vikas Das', 'Male', datetime.date(2010, 10, 24), '9707079880', 'Mumbai')
# (23, 'Priya Mehta', 'Female', datetime.date(1991, 7, 3), '9394257570', 'Kolkata')
# (24, 'Pooja Sharma', 'Female', datetime.date(2007, 3, 7), '9684320600', 'Kolkata')
# (25, 'Rohit Sharma', 'Male', datetime.date(2010, 2, 24), '9347301708', 'Pune')
# (26, 'Anjali Mehta', 'Female', datetime.date(1998, 12, 15), '9286386774', 'Pune')
# (27, 'Aditya Reddy', 'Male', datetime.date(2006, 7, 6), '9821486566', 'Indore')
# (28, 'Pooja Das', 'Female', datetime.date(2004, 7, 23), '9101102821', 'Kolkata')
# (29, 'Suresh Das', 'Male', datetime.date(1996, 11, 21), '9241884054', 'Lucknow')
# (30, 'Riya Verma', 'Female', datetime.date(2009, 2, 26), '9726777032', 'Pune')
# (31, 'Ankit Iyer', 'Male', datetime.date(2004, 2, 4), '9302774240', 'Jaipur')
# (32, 'Amit Das', 'Male', datetime.date(1991, 5, 23), '9121598463', 'Chennai')
# (33, 'Rohit Verma', 'Male', datetime.date(1999, 12, 19), '9371944255', 'Jaipur')
# (34, 'Suresh Kumar', 'Male', datetime.date(2000, 6, 7), '9884886925', 'Hyderabad')
# (35, 'Ravi Verma', 'Male', datetime.date(1997, 4, 21), '9430840044', 'Lucknow')
# (36, 'Arjun Singh', 'Male', datetime.date(1994, 6, 26), '9635329404', 'Mumbai')
# (37, 'Suresh Kumar', 'Male', datetime.date(1991, 6, 3), '9898019277', 'Mumbai')
# (38, 'Riya Sharma', 'Female', datetime.date(2005, 9, 1), '9696394657', 'Lucknow')
# (39, 'Neha Singh', 'Female', datetime.date(2007, 12, 24), '9471934385', 'Chennai')
# (40, 'Nisha Verma', 'Female', datetime.date(1995, 3, 30), '9198358558', 'Bengaluru')
# (41, 'Kunal Patel', 'Male', datetime.date(2004, 3, 2), '9119980363', 'Mumbai')
# (42, 'Anjali Iyer', 'Female', datetime.date(1998, 2, 7), '9335967153', 'Pune')
# (43, 'Anjali Patel', 'Female', datetime.date(1996, 4, 27), '9447228696', 'Chennai')
# (44, 'Kunal Kumar', 'Male', datetime.date(1998, 1, 12), '9663785008', 'Jaipur')
# (45, 'Amit Mehta', 'Male', datetime.date(1997, 8, 26), '9915483959', 'Lucknow')
# (46, 'Priya Reddy', 'Female', datetime.date(1996, 9, 7), '9909369255', 'Hyderabad')
# (47, 'Ravi Mehta', 'Male', datetime.date(1999, 9, 1), '9982062228', 'Pune')
# (48, 'Amit Iyer', 'Male', datetime.date(1995, 4, 11), '9106149347', 'Chennai')
# (49, 'Kavya Das', 'Female', datetime.date(2000, 3, 17), '9638560814', 'Mumbai')
# (50, 'Aarti Reddy', 'Female', datetime.date(2006, 12, 13), '9974896488', 'Lucknow')
# (51, 'Nisha Kumar', 'Female', datetime.date(2010, 11, 3), '9760374665', 'Lucknow')
# (52, 'Aditya Iyer', 'Male', datetime.date(2005, 4, 7), '9244290032', 'Delhi')
# (53, 'Suresh Iyer', 'Male', datetime.date(1992, 2, 12), '9220632239', 'Lucknow')
# (54, 'Riya Kumar', 'Female', datetime.date(1990, 3, 30), '9665018994', 'Mumbai')
# (55, 'Isha Singh', 'Female', datetime.date(2010, 5, 9), '9517902838', 'Indore')
# (56, 'Priya Reddy', 'Female', datetime.date(2007, 7, 18), '9733327254', 'Lucknow')
# (57, 'Aditya Das', 'Male', datetime.date(1997, 4, 21), '9869557747', 'Indore')
# (58, 'Rahul Sharma', 'Male', datetime.date(2000, 2, 5), '9177538509', 'Indore')
# (59, 'Rohit Mehta', 'Male', datetime.date(1993, 7, 19), '9808127456', 'Jaipur')
# (60, 'Nisha Sharma', 'Female', datetime.date(2001, 7, 27), '9257091157', 'Kolkata')
# (61, 'Nisha Mehta', 'Female', datetime.date(2009, 7, 23), '9685247596', 'Jaipur')
# (62, 'Aarti Singh', 'Female', datetime.date(2003, 7, 23), '9675615554', 'Jaipur')
# (63, 'Neha Iyer', 'Female', datetime.date(1993, 3, 4), '9391785262', 'Lucknow')
# (64, 'Pooja Gupta', 'Female', datetime.date(2005, 1, 15), '9702319815', 'Chennai')
# (65, 'Nisha Mehta', 'Female', datetime.date(1993, 5, 9), '9241064817', 'Chennai')
# (66, 'Ravi Iyer', 'Male', datetime.date(1996, 2, 13), '9282669138', 'Bengaluru')
# (67, 'Riya Patel', 'Female', datetime.date(2005, 2, 13), '9226768125', 'Delhi')
# (68, 'Vikas Mehta', 'Male', datetime.date(2007, 7, 25), '9595749591', 'Kolkata')
# (69, 'Anjali Das', 'Female', datetime.date(2003, 8, 13), '9359197205', 'Kolkata')
# (70, 'Priya Verma', 'Female', datetime.date(2006, 5, 3), '9252569729', 'Jaipur')
# (71, 'Ankit Das', 'Male', datetime.date(1998, 5, 7), '9534798777', 'Delhi')
# (72, 'Rahul Iyer', 'Male', datetime.date(1999, 3, 5), '9800432919', 'Lucknow')
# (73, 'Amit Sharma', 'Male', datetime.date(2002, 3, 5), '9108430034', 'Pune')
# (74, 'Riya Das', 'Female', datetime.date(2001, 1, 25), '9438194160', 'Jaipur')
# (75, 'Anjali Reddy', 'Female', datetime.date(1995, 6, 3), '9467691492', 'Mumbai')
# (76, 'Isha Kumar', 'Female', datetime.date(2007, 4, 12), '9786073602', 'Mumbai')
# (77, 'Sneha Singh', 'Female', datetime.date(1995, 1, 27), '9363056990', 'Bengaluru')
# (78, 'Priya Mehta', 'Female', datetime.date(2005, 7, 12), '9356900511', 'Lucknow')
# (79, 'Suresh Verma', 'Male', datetime.date(2005, 10, 23), '9818996248', 'Pune')
# (80, 'Ravi Reddy', 'Male', datetime.date(1997, 4, 2), '9694295543', 'Indore')
# (81, 'Neha Sharma', 'Female', datetime.date(1993, 10, 21), '9441353685', 'Delhi')
# (82, 'Riya Mehta', 'Female', datetime.date(2004, 5, 21), '9926821120', 'Pune')
# (83, 'Isha Kumar', 'Female', datetime.date(2002, 5, 31), '9527617568', 'Delhi')
# (84, 'Rahul Verma', 'Male', datetime.date(2006, 3, 1), '9850170765', 'Delhi')
# (85, 'Rohit Patel', 'Male', datetime.date(2005, 2, 12), '9266339733', 'Bengaluru')
# (86, 'Pooja Reddy', 'Female', datetime.date(2000, 6, 14), '9472352613', 'Lucknow')
# (87, 'Rohit Gupta', 'Male', datetime.date(2002, 11, 19), '9938167930', 'Hyderabad')
# (88, 'Pooja Das', 'Female', datetime.date(2003, 8, 14), '9155874611', 'Kolkata')
# (89, 'Priya Das', 'Female', datetime.date(1995, 11, 13), '9225366403', 'Bengaluru')
# (90, 'Priya Reddy', 'Female', datetime.date(1994, 4, 20), '9570864386', 'Kolkata')
# (91, 'Amit Patel', 'Male', datetime.date(2003, 10, 17), '9141945594', 'Lucknow')
# (92, 'Rohit Patel', 'Male', datetime.date(1991, 1, 4), '9528430524', 'Lucknow')
# (93, 'Kunal Mehta', 'Male', datetime.date(1991, 6, 7), '9888536717', 'Pune')
# (94, 'Priya Patel', 'Female', datetime.date(2008, 9, 24), '9682806343', 'Hyderabad')
# (95, 'Amit Das', 'Male', datetime.date(2004, 9, 26), '9609267786', 'Indore')
# (96, 'Isha Iyer', 'Female', datetime.date(2001, 4, 9), '9442683110', 'Bengaluru')
# (97, 'Isha Reddy', 'Female', datetime.date(1999, 3, 14), '9139371658', 'Mumbai')
# (98, 'Anjali Das', 'Female', datetime.date(2008, 10, 1), '9383175490', 'Indore')
# (99, 'Anjali Singh', 'Female', datetime.date(2002, 3, 27), '9285160572', 'Lucknow')
# (100, 'Kunal Das', 'Male', datetime.date(2008, 11, 9), '9826819369', 'Bengaluru')
# (101, 'Nisha Verma', 'Female', datetime.date(2001, 7, 4), '9931008575', 'Chennai')
# (102, 'Ravi Gupta', 'Male', datetime.date(2000, 3, 8), '9449911338', 'Kolkata')
# (103, 'Vikas Verma', 'Male', datetime.date(2009, 10, 28), '9416876787', 'Bengaluru')
# (104, 'Suresh Mehta', 'Male', datetime.date(2000, 3, 30), '9120455364', 'Jaipur')
# (105, 'Vikas Iyer', 'Male', datetime.date(2001, 8, 6), '9581816334', 'Lucknow')
# (106, 'Isha Sharma', 'Female', datetime.date(2006, 10, 7), '9763359685', 'Hyderabad')
# (107, 'Arjun Verma', 'Male', datetime.date(2003, 12, 15), '9435260433', 'Delhi')
# (108, 'Neha Singh', 'Female', datetime.date(1990, 11, 10), '9440640508', 'Mumbai')
# (109, 'Rohit Mehta', 'Male', datetime.date(1999, 12, 9), '9659391796', 'Delhi')
# (110, 'Priya Patel', 'Female', datetime.date(2007, 6, 21), '9939220782', 'Indore')
# (111, 'Ankit Verma', 'Male', datetime.date(2004, 6, 13), '9838490243', 'Mumbai')
# (112, 'Ankit Verma', 'Male', datetime.date(2006, 7, 17), '9135365812', 'Lucknow')
# (113, 'Suresh Singh', 'Male', datetime.date(2010, 8, 24), '9171600518', 'Pune')
# (114, 'Aarti Iyer', 'Female', datetime.date(1999, 10, 13), '9496148215', 'Delhi')
# (115, 'Kunal Sharma', 'Male', datetime.date(2005, 7, 17), '9718289189', 'Lucknow')
# (116, 'Kavya Kumar', 'Female', datetime.date(2003, 7, 26), '9638651069', 'Chennai')
# (117, 'Pooja Patel', 'Female', datetime.date(1991, 2, 3), '9532382338', 'Kolkata')
# (118, 'Kunal Das', 'Male', datetime.date(2004, 4, 16), '9976350959', 'Kolkata')
# (119, 'Riya Patel', 'Female', datetime.date(2000, 10, 14), '9797395873', 'Pune')
# (120, 'Amit Das', 'Male', datetime.date(1991, 12, 17), '9563283475', 'Lucknow')
# (121, 'Sneha Das', 'Female', datetime.date(1994, 12, 20), '9157958972', 'Pune')
# (122, 'Isha Patel', 'Female', datetime.date(1991, 8, 29), '9747487249', 'Bengaluru')
# (123, 'Isha Mehta', 'Female', datetime.date(2009, 5, 24), '9302568981', 'Bengaluru')
# (124, 'Sneha Patel', 'Female', datetime.date(2006, 7, 30), '9109327842', 'Indore')
# (125, 'Ankit Reddy', 'Male', datetime.date(1992, 2, 1), '9790579921', 'Kolkata')
# (126, 'Pooja Patel', 'Female', datetime.date(1995, 11, 7), '9893356941', 'Bengaluru')
# (127, 'Pooja Kumar', 'Female', datetime.date(2005, 5, 12), '9379875433', 'Lucknow')
# (128, 'Suresh Mehta', 'Male', datetime.date(1996, 8, 27), '9393895501', 'Jaipur')
# (129, 'Kavya Kumar', 'Female', datetime.date(2009, 11, 8), '9774398808', 'Hyderabad')
# (130, 'Rahul Singh', 'Male', datetime.date(2003, 6, 29), '9958577654', 'Kolkata')
# (131, 'Rohit Verma', 'Male', datetime.date(1995, 6, 25), '9144555045', 'Bengaluru')
# (132, 'Vikas Patel', 'Male', datetime.date(2010, 10, 10), '9451650864', 'Lucknow')
# (133, 'Ravi Patel', 'Male', datetime.date(2008, 7, 17), '9975377498', 'Mumbai')
# (134, 'Ravi Mehta', 'Male', datetime.date(1995, 8, 27), '9411188283', 'Chennai')
# (135, 'Ankit Das', 'Male', datetime.date(2009, 9, 30), '9148922353', 'Bengaluru')
# (136, 'Aditya Singh', 'Male', datetime.date(1990, 6, 9), '9359436495', 'Delhi')
# (137, 'Aarti Iyer', 'Female', datetime.date(2002, 4, 22), '9551688254', 'Delhi')
# (138, 'Kunal Reddy', 'Male', datetime.date(1996, 10, 27), '9984088567', 'Pune')
# (139, 'Riya Iyer', 'Female', datetime.date(2009, 7, 1), '9974529432', 'Pune')
# (140, 'Kavya Singh', 'Female', datetime.date(2006, 2, 1), '9566785135', 'Hyderabad')
# (141, 'Isha Kumar', 'Female', datetime.date(1993, 2, 15), '9574434172', 'Indore')
# (142, 'Anjali Gupta', 'Female', datetime.date(2008, 5, 18), '9521259432', 'Delhi')
# (143, 'Aarti Singh', 'Female', datetime.date(1992, 8, 6), '9756992473', 'Indore')
# (144, 'Kavya Kumar', 'Female', datetime.date(1996, 7, 3), '9333387901', 'Mumbai')
# (145, 'Suresh Reddy', 'Male', datetime.date(2002, 3, 21), '9541386270', 'Lucknow')
# (146, 'Isha Das', 'Female', datetime.date(1995, 10, 20), '9506062194', 'Mumbai')
# (147, 'Aarti Kumar', 'Female', datetime.date(1998, 1, 5), '9604237381', 'Lucknow')
# (148, 'Ravi Singh', 'Male', datetime.date(2008, 5, 6), '9376121123', 'Jaipur')
# (149, 'Kunal Iyer', 'Male', datetime.date(1991, 6, 28), '9580430543', 'Lucknow')
# (150, 'Amit Mehta', 'Male', datetime.date(2010, 2, 1), '9244474728', 'Pune')
# (151, 'Amit Sharma', 'Male', datetime.date(2006, 7, 15), '9237770112', 'Indore')
# (152, 'Isha Kumar', 'Female', datetime.date(1999, 4, 25), '9231198144', 'Indore')
# (153, 'Nisha Iyer', 'Female', datetime.date(2005, 4, 14), '9955866785', 'Mumbai')
# (154, 'Isha Patel', 'Female', datetime.date(1991, 6, 20), '9614214885', 'Indore')
# (155, 'Suresh Verma', 'Male', datetime.date(1993, 11, 21), '9766327859', 'Bengaluru')
# (156, 'Vikas Mehta', 'Male', datetime.date(2004, 1, 30), '9968433834', 'Mumbai')
# (157, 'Isha Reddy', 'Female', datetime.date(1993, 5, 19), '9276122770', 'Bengaluru')
# (158, 'Anjali Patel', 'Female', datetime.date(2010, 4, 4), '9667553173', 'Pune')
# (159, 'Rahul Iyer', 'Male', datetime.date(1991, 1, 20), '9537215161', 'Pune')
# (160, 'Nisha Mehta', 'Female', datetime.date(2008, 6, 6), '9715671792', 'Bengaluru')
# (161, 'Vikas Kumar', 'Male', datetime.date(1996, 4, 27), '9278804756', 'Chennai')
# (162, 'Priya Verma', 'Female', datetime.date(2001, 6, 23), '9735675941', 'Kolkata')
# (163, 'Rohit Verma', 'Male', datetime.date(1995, 1, 13), '9971759406', 'Kolkata')
# (164, 'Anjali Singh', 'Female', datetime.date(2000, 7, 18), '9488209812', 'Jaipur')
# (165, 'Pooja Verma', 'Female', datetime.date(2006, 4, 26), '9636698267', 'Lucknow')
# (166, 'Rahul Reddy', 'Male', datetime.date(2009, 12, 5), '9988322067', 'Chennai')
# (167, 'Pooja Kumar', 'Female', datetime.date(2007, 11, 23), '9767070811', 'Delhi')
# (168, 'Aditya Das', 'Male', datetime.date(2001, 11, 9), '9126971062', 'Chennai')
# (169, 'Sneha Reddy', 'Female', datetime.date(2004, 10, 30), '9216071752', 'Indore')
# (170, 'Isha Reddy', 'Female', datetime.date(1991, 9, 3), '9975498545', 'Lucknow')
# (171, 'Aarti Kumar', 'Female', datetime.date(2002, 3, 8), '9355299837', 'Pune')
# (172, 'Kunal Iyer', 'Male', datetime.date(1991, 3, 3), '9454459974', 'Kolkata')
# (173, 'Sneha Kumar', 'Female', datetime.date(1997, 11, 8), '9221442035', 'Jaipur')
# (174, 'Amit Patel', 'Male', datetime.date(2008, 9, 19), '9345813854', 'Pune')
# (175, 'Nisha Gupta', 'Female', datetime.date(2003, 6, 7), '9143145997', 'Delhi')
# (176, 'Sneha Kumar', 'Female', datetime.date(1999, 3, 24), '9280646048', 'Indore')
# (177, 'Vikas Gupta', 'Male', datetime.date(2006, 6, 27), '9973910336', 'Chennai')
# (178, 'Nisha Das', 'Female', datetime.date(2008, 1, 11), '9749935854', 'Hyderabad')
# (179, 'Vikas Singh', 'Male', datetime.date(2004, 10, 7), '9152531457', 'Lucknow')
# (180, 'Arjun Sharma', 'Male', datetime.date(2000, 4, 15), '9213382992', 'Kolkata')
# (181, 'Priya Patel', 'Female', datetime.date(1996, 12, 9), '9205971047', 'Delhi')
# (182, 'Aarti Singh', 'Female', datetime.date(1990, 5, 2), '9534420909', 'Delhi')
# (183, 'Kavya Singh', 'Female', datetime.date(1993, 5, 10), '9163211704', 'Delhi')
# (184, 'Amit Iyer', 'Male', datetime.date(2001, 1, 16), '9720251220', 'Chennai')
# (185, 'Aarti Verma', 'Female', datetime.date(2005, 6, 25), '9373883802', 'Chennai')
# (186, 'Sneha Das', 'Female', datetime.date(1997, 7, 31), '9996902498', 'Hyderabad')
# (187, 'Ankit Patel', 'Male', datetime.date(1992, 8, 17), '9516691430', 'Pune')
# (188, 'Pooja Das', 'Female', datetime.date(1990, 1, 6), '9605731942', 'Kolkata')
# (189, 'Anjali Verma', 'Female', datetime.date(2009, 1, 28), '9340897251', 'Delhi')
# (190, 'Isha Kumar', 'Female', datetime.date(2006, 1, 17), '9566338103', 'Lucknow')
# (191, 'Isha Kumar', 'Female', datetime.date(2008, 6, 3), '9402700571', 'Lucknow')
# (192, 'Amit Gupta', 'Male', datetime.date(2004, 3, 12), '9522682380', 'Pune')
# (193, 'Amit Das', 'Male', datetime.date(2006, 5, 9), '9945742088', 'Delhi')
# (194, 'Pooja Sharma', 'Female', datetime.date(1994, 6, 11), '9451631251', 'Pune')
# (195, 'Isha Verma', 'Female', datetime.date(1990, 5, 20), '9122612205', 'Bengaluru')
# (196, 'Vikas Sharma', 'Male', datetime.date(2004, 8, 12), '9181964462', 'Chennai')
# (197, 'Anjali Das', 'Female', datetime.date(1994, 1, 2), '9448113505', 'Mumbai')
# (198, 'Arjun Singh', 'Male', datetime.date(2002, 12, 14), '9676517769', 'Hyderabad')
# (199, 'Rohit Singh', 'Male', datetime.date(2005, 1, 21), '9260234736', 'Chennai')
# (200, 'Neha Kumar', 'Female', datetime.date(1994, 1, 13), '9300178523', 'Jaipur')
# (201, 'Isha Gupta', 'Female', datetime.date(2009, 1, 10), '9800377808', 'Kolkata')
# (202, 'Priya Iyer', 'Female', datetime.date(2004, 12, 14), '9135688868', 'Pune')
# (203, 'Pooja Singh', 'Female', datetime.date(1994, 5, 27), '9555053242', 'Jaipur')
# (204, 'Aarti Sharma', 'Female', datetime.date(2003, 3, 11), '9803410785', 'Chennai')
# (205, 'Aditya Singh', 'Male', datetime.date(2006, 4, 30), '9850899058', 'Chennai')
# (206, 'Suresh Kumar', 'Male', datetime.date(2008, 7, 24), '9640778648', 'Mumbai')
# (207, 'Pooja Kumar', 'Female', datetime.date(2003, 12, 24), '9778410252', 'Hyderabad')
# (208, 'Neha Das', 'Female', datetime.date(2004, 1, 9), '9599963269', 'Hyderabad')
# (209, 'Vikas Das', 'Male', datetime.date(2010, 8, 17), '9735909527', 'Kolkata')
# (210, 'Amit Sharma', 'Male', datetime.date(2001, 6, 2), '9484137172', 'Jaipur')
# (211, 'Aarti Gupta', 'Female', datetime.date(1998, 2, 24), '9384644964', 'Hyderabad')
# (212, 'Sneha Das', 'Female', datetime.date(2008, 11, 25), '9697195584', 'Bengaluru')
# (213, 'Aditya Singh', 'Male', datetime.date(1998, 5, 19), '9158770382', 'Delhi')
# (214, 'Pooja Das', 'Female', datetime.date(2009, 7, 10), '9360852946', 'Indore')
# (215, 'Vikas Singh', 'Male', datetime.date(1997, 10, 23), '9389198135', 'Mumbai')
# (216, 'Pooja Das', 'Female', datetime.date(1993, 8, 4), '9460941467', 'Bengaluru')
# (217, 'Priya Mehta', 'Female', datetime.date(2004, 4, 26), '9694069313', 'Lucknow')
# (218, 'Ravi Reddy', 'Male', datetime.date(1997, 2, 24), '9666264454', 'Bengaluru')
# (219, 'Kavya Das', 'Female', datetime.date(2000, 4, 6), '9795907656', 'Pune')
# (220, 'Sneha Verma', 'Female', datetime.date(1992, 11, 29), '9501338689', 'Chennai')
# (221, 'Rahul Kumar', 'Male', datetime.date(2007, 2, 3), '9305221010', 'Kolkata')
# (222, 'Pooja Iyer', 'Female', datetime.date(2002, 5, 24), '9838456572', 'Chennai')
# (223, 'Isha Iyer', 'Female', datetime.date(1993, 5, 18), '9842053273', 'Hyderabad')
# (224, 'Arjun Mehta', 'Male', datetime.date(1995, 8, 9), '9769509570', 'Chennai')
# (225, 'Nisha Kumar', 'Female', datetime.date(2010, 3, 3), '9923287247', 'Delhi')
# (226, 'Rahul Verma', 'Male', datetime.date(1994, 1, 12), '9695878187', 'Pune')
# (227, 'Pooja Mehta', 'Female', datetime.date(1999, 1, 26), '9476553147', 'Delhi')
# (228, 'Neha Sharma', 'Female', datetime.date(2008, 3, 6), '9311510845', 'Hyderabad')
# (229, 'Anjali Singh', 'Female', datetime.date(2004, 10, 17), '9163238539', 'Lucknow')
# (230, 'Suresh Gupta', 'Male', datetime.date(1995, 12, 8), '9860420594', 'Indore')
# (231, 'Vikas Patel', 'Male', datetime.date(2000, 10, 4), '9225877396', 'Chennai')
# (232, 'Vikas Reddy', 'Male', datetime.date(2010, 3, 20), '9119949716', 'Indore')
# (233, 'Ankit Das', 'Male', datetime.date(2009, 1, 12), '9374013624', 'Pune')
# (234, 'Isha Singh', 'Female', datetime.date(2001, 11, 28), '9715715027', 'Chennai')
# (235, 'Riya Singh', 'Female', datetime.date(2007, 2, 21), '9564635375', 'Mumbai')
# (236, 'Pooja Das', 'Female', datetime.date(2002, 10, 7), '9371254889', 'Mumbai')
# (237, 'Amit Verma', 'Male', datetime.date(2009, 2, 24), '9908862995', 'Bengaluru')
# (238, 'Aarti Sharma', 'Female', datetime.date(2001, 11, 4), '9935683408', 'Indore')
# (239, 'Anjali Reddy', 'Female', datetime.date(2002, 5, 11), '9744430070', 'Delhi')
# (240, 'Sneha Patel', 'Female', datetime.date(2006, 3, 24), '9307521082', 'Indore')
# (241, 'Rahul Sharma', 'Male', datetime.date(1994, 10, 14), '9468625339', 'Mumbai')
# (242, 'Ankit Kumar', 'Male', datetime.date(1990, 3, 5), '9690527658', 'Delhi')
# (243, 'Pooja Gupta', 'Female', datetime.date(1992, 10, 1), '9608494741', 'Indore')
# (244, 'Neha Singh', 'Female', datetime.date(1997, 4, 23), '9452977770', 'Lucknow')
# (245, 'Aarti Patel', 'Female', datetime.date(1998, 7, 15), '9994127660', 'Bengaluru')
# (246, 'Anjali Sharma', 'Female', datetime.date(2008, 1, 14), '9842194808', 'Mumbai')
# (247, 'Nisha Sharma', 'Female', datetime.date(1991, 4, 16), '9694128339', 'Chennai')
# (248, 'Ravi Verma', 'Male', datetime.date(2003, 11, 3), '9169055825', 'Chennai')
# (249, 'Riya Sharma', 'Female', datetime.date(1991, 5, 13), '9559304493', 'Delhi')
# (250, 'Nisha Iyer', 'Female', datetime.date(2003, 7, 17), '9888538852', 'Delhi')
# (251, 'Riya Verma', 'Female', datetime.date(1998, 9, 22), '9715533251', 'Hyderabad')
# (252, 'Neha Singh', 'Female', datetime.date(2005, 4, 20), '9612327056', 'Indore')
# (253, 'Ravi Verma', 'Male', datetime.date(2007, 8, 16), '9851368673', 'Mumbai')
# (254, 'Aditya Verma', 'Male', datetime.date(1993, 4, 12), '9950633911', 'Mumbai')
# (255, 'Pooja Iyer', 'Female', datetime.date(1996, 1, 30), '9860394986', 'Indore')
# (256, 'Ravi Sharma', 'Male', datetime.date(2009, 12, 12), '9291330689', 'Lucknow')
# (257, 'Priya Verma', 'Female', datetime.date(1999, 7, 28), '9761097073', 'Jaipur')
# (258, 'Pooja Patel', 'Female', datetime.date(2007, 3, 6), '9386343954', 'Kolkata')
# (259, 'Sneha Kumar', 'Female', datetime.date(2002, 10, 14), '9853419107', 'Pune')
# (260, 'Anjali Reddy', 'Female', datetime.date(1994, 12, 19), '9482488624', 'Kolkata')
# (261, 'Sneha Patel', 'Female', datetime.date(1996, 3, 25), '9929665823', 'Chennai')
# (262, 'Kunal Kumar', 'Male', datetime.date(1993, 1, 17), '9174697976', 'Mumbai')
# (263, 'Rahul Gupta', 'Male', datetime.date(2010, 1, 15), '9679394429', 'Hyderabad')
# (264, 'Arjun Reddy', 'Male', datetime.date(2001, 1, 24), '9183638091', 'Delhi')
# (265, 'Priya Patel', 'Female', datetime.date(1999, 5, 31), '9476101616', 'Kolkata')
# (266, 'Suresh Mehta', 'Male', datetime.date(1996, 3, 29), '9226848253', 'Mumbai')
# (267, 'Anjali Mehta', 'Female', datetime.date(1998, 4, 9), '9830141728', 'Hyderabad')
# (268, 'Aditya Singh', 'Male', datetime.date(1991, 9, 8), '9539626331', 'Bengaluru')
# (269, 'Rohit Mehta', 'Male', datetime.date(1993, 10, 21), '9364841847', 'Lucknow')
# (270, 'Kavya Singh', 'Female', datetime.date(1998, 1, 5), '9532508368', 'Lucknow')
# (271, 'Riya Mehta', 'Female', datetime.date(1991, 4, 15), '9484305759', 'Mumbai')
# (272, 'Riya Gupta', 'Female', datetime.date(2006, 12, 30), '9130906728', 'Chennai')
# (273, 'Rohit Reddy', 'Male', datetime.date(1993, 12, 13), '9574839896', 'Jaipur')
# (274, 'Riya Singh', 'Female', datetime.date(2007, 5, 26), '9992201003', 'Jaipur')
# (275, 'Rohit Reddy', 'Male', datetime.date(1998, 11, 22), '9848152568', 'Bengaluru')
# (276, 'Isha Reddy', 'Female', datetime.date(2004, 4, 16), '9250254338', 'Kolkata')
# (277, 'Rohit Mehta', 'Male', datetime.date(2008, 2, 26), '9446162193', 'Indore')
# (278, 'Rahul Singh', 'Male', datetime.date(2009, 6, 10), '9793141727', 'Chennai')
# (279, 'Vikas Das', 'Male', datetime.date(1991, 2, 25), '9103957136', 'Mumbai')
# (280, 'Riya Das', 'Female', datetime.date(1996, 9, 14), '9823680486', 'Kolkata')
# (281, 'Nisha Patel', 'Female', datetime.date(1992, 4, 7), '9724263769', 'Pune')
# (282, 'Anjali Iyer', 'Female', datetime.date(2003, 4, 6), '9464557102', 'Mumbai')
# (283, 'Kunal Gupta', 'Male', datetime.date(2006, 11, 23), '9781260133', 'Mumbai')
# (284, 'Nisha Gupta', 'Female', datetime.date(2004, 6, 23), '9283267634', 'Bengaluru')
# (285, 'Rahul Das', 'Male', datetime.date(1994, 11, 22), '9907981689', 'Mumbai')
# (286, 'Sneha Mehta', 'Female', datetime.date(2006, 1, 16), '9145318958', 'Indore')
# (287, 'Kavya Iyer', 'Female', datetime.date(1995, 10, 20), '9983165000', 'Pune')
# (288, 'Sneha Gupta', 'Female', datetime.date(1998, 10, 6), '9315306211', 'Lucknow')
# (289, 'Aarti Patel', 'Female', datetime.date(2007, 8, 19), '9795812506', 'Mumbai')
# (290, 'Riya Sharma', 'Female', datetime.date(2006, 5, 22), '9174534469', 'Lucknow')
# (291, 'Kunal Singh', 'Male', datetime.date(1995, 10, 6), '9273876700', 'Bengaluru')
# (292, 'Pooja Verma', 'Female', datetime.date(2000, 10, 5), '9456886236', 'Indore')
# (293, 'Kavya Reddy', 'Female', datetime.date(2006, 11, 2), '9458746273', 'Bengaluru')
# (294, 'Pooja Iyer', 'Female', datetime.date(1999, 8, 28), '9218583300', 'Jaipur')
# (295, 'Kavya Gupta', 'Female', datetime.date(2008, 4, 4), '9704603899', 'Kolkata')
# (296, 'Suresh Reddy', 'Male', datetime.date(1998, 6, 25), '9198504232', 'Mumbai')
# (297, 'Amit Sharma', 'Male', datetime.date(2000, 1, 19), '9700709966', 'Mumbai')
# (298, 'Riya Patel', 'Female', datetime.date(2001, 6, 17), '9714139090', 'Mumbai')
# (299, 'Aditya Mehta', 'Male', datetime.date(1999, 2, 17), '9536191330', 'Mumbai')
# (300, 'Priya Gupta', 'Female', datetime.date(2008, 5, 3), '9578188453', 'Chennai')
# (301, 'Neha Iyer', 'Female', datetime.date(2005, 9, 21), '9394829759', 'Indore')
# (302, 'Sneha Mehta', 'Female', datetime.date(2002, 5, 26), '9541803658', 'Indore')
# (303, 'Rohit Kumar', 'Male', datetime.date(2003, 7, 12), '9263493221', 'Lucknow')
# (304, 'Riya Singh', 'Female', datetime.date(2005, 3, 30), '9682721449', 'Bengaluru')
# (305, 'Neha Mehta', 'Female', datetime.date(2008, 5, 21), '9494973739', 'Kolkata')
# (306, 'Aarti Singh', 'Female', datetime.date(1995, 6, 20), '9724558931', 'Bengaluru')
# (307, 'Kunal Verma', 'Male', datetime.date(1995, 12, 22), '9919820161', 'Kolkata')
# (308, 'Isha Patel', 'Female', datetime.date(2006, 5, 16), '9383846611', 'Indore')
# (309, 'Kunal Reddy', 'Male', datetime.date(1992, 7, 4), '9417279528', 'Delhi')
# (310, 'Pooja Reddy', 'Female', datetime.date(2005, 11, 11), '9402033472', 'Delhi')
# (311, 'Rahul Iyer', 'Male', datetime.date(1998, 7, 16), '9569371382', 'Bengaluru')
# (312, 'Nisha Sharma', 'Female', datetime.date(1999, 7, 29), '9285645474', 'Indore')
# (313, 'Aditya Patel', 'Male', datetime.date(2003, 9, 5), '9833641637', 'Pune')
# (314, 'Vikas Singh', 'Male', datetime.date(1990, 11, 27), '9974736770', 'Chennai')
# (315, 'Ankit Singh', 'Male', datetime.date(2007, 6, 12), '9735348667', 'Chennai')
# (316, 'Neha Sharma', 'Female', datetime.date(2004, 12, 19), '9617479671', 'Jaipur')
# (317, 'Neha Verma', 'Female', datetime.date(2003, 5, 4), '9725403947', 'Chennai')
# (318, 'Ravi Das', 'Male', datetime.date(2010, 3, 7), '9829167389', 'Indore')
# (319, 'Riya Singh', 'Female', datetime.date(1999, 6, 12), '9646738862', 'Delhi')
# (320, 'Nisha Gupta', 'Female', datetime.date(1990, 10, 24), '9751244894', 'Mumbai')
# (321, 'Kavya Reddy', 'Female', datetime.date(2004, 11, 20), '9746053041', 'Hyderabad')
# (322, 'Priya Iyer', 'Female', datetime.date(1997, 7, 2), '9362258347', 'Kolkata')
# (323, 'Aarti Patel', 'Female', datetime.date(2005, 6, 23), '9813846519', 'Chennai')
# (324, 'Amit Sharma', 'Male', datetime.date(1997, 9, 22), '9224396098', 'Lucknow')
# (325, 'Vikas Das', 'Male', datetime.date(2006, 4, 23), '9552937438', 'Mumbai')
# (326, 'Riya Das', 'Female', datetime.date(2005, 8, 7), '9778604083', 'Kolkata')
# (327, 'Vikas Verma', 'Male', datetime.date(2007, 8, 21), '9871616886', 'Kolkata')
# (328, 'Kunal Iyer', 'Male', datetime.date(1998, 10, 1), '9738198045', 'Kolkata')
# (329, 'Rohit Sharma', 'Male', datetime.date(2006, 4, 24), '9257652743', 'Kolkata')
# (330, 'Isha Singh', 'Female', datetime.date(2002, 10, 20), '9755802438', 'Bengaluru')
# (331, 'Pooja Sharma', 'Female', datetime.date(2001, 8, 30), '9270243262', 'Lucknow')
# (332, 'Rahul Singh', 'Male', datetime.date(2006, 10, 1), '9817725708', 'Chennai')
# (333, 'Riya Sharma', 'Female', datetime.date(1993, 2, 25), '9805278767', 'Delhi')
# (334, 'Riya Gupta', 'Female', datetime.date(1992, 9, 17), '9340128873', 'Mumbai')
# (335, 'Kunal Patel', 'Male', datetime.date(2002, 10, 4), '9586405031', 'Bengaluru')
# (336, 'Rohit Patel', 'Male', datetime.date(1993, 8, 19), '9796482979', 'Mumbai')
# (337, 'Neha Gupta', 'Female', datetime.date(2010, 7, 28), '9506041365', 'Bengaluru')
# (338, 'Kunal Reddy', 'Male', datetime.date(2006, 11, 27), '9706984682', 'Delhi')
# (339, 'Isha Sharma', 'Female', datetime.date(1997, 2, 13), '9227802641', 'Kolkata')
# (340, 'Isha Patel', 'Female', datetime.date(1993, 4, 4), '9278797423', 'Chennai')
# (341, 'Anjali Verma', 'Female', datetime.date(2005, 5, 10), '9526283123', 'Lucknow')
# (342, 'Aarti Reddy', 'Female', datetime.date(2007, 12, 29), '9973622685', 'Delhi')
# (343, 'Rohit Gupta', 'Male', datetime.date(1999, 2, 22), '9328948248', 'Pune')
# (344, 'Aarti Patel', 'Female', datetime.date(2008, 6, 28), '9561712146', 'Lucknow')
# (345, 'Priya Gupta', 'Female', datetime.date(1995, 5, 16), '9373647726', 'Indore')
# (346, 'Vikas Das', 'Male', datetime.date(1999, 3, 24), '9232979628', 'Mumbai')
# (347, 'Pooja Gupta', 'Female', datetime.date(2008, 7, 18), '9189192021', 'Pune')
# (348, 'Riya Verma', 'Female', datetime.date(1990, 2, 22), '9852100657', 'Chennai')
# (349, 'Kavya Das', 'Female', datetime.date(1990, 7, 16), '9698368145', 'Mumbai')
# (350, 'Neha Verma', 'Female', datetime.date(1998, 4, 17), '9852000684', 'Bengaluru')
# (351, 'Arjun Kumar', 'Male', datetime.date(2002, 9, 13), '9214397117', 'Hyderabad')
# (352, 'Suresh Das', 'Male', datetime.date(1992, 9, 18), '9682424655', 'Indore')
# (353, 'Pooja Kumar', 'Female', datetime.date(1990, 11, 28), '9743953051', 'Hyderabad')
# (354, 'Isha Reddy', 'Female', datetime.date(2006, 6, 26), '9518376345', 'Pune')
# (355, 'Rohit Das', 'Male', datetime.date(2001, 2, 5), '9727031659', 'Indore')
# (356, 'Isha Reddy', 'Female', datetime.date(2010, 9, 23), '9719396459', 'Delhi')
# (357, 'Riya Verma', 'Female', datetime.date(1998, 12, 24), '9639585466', 'Pune')
# (358, 'Rahul Gupta', 'Male', datetime.date(2004, 6, 28), '9943593645', 'Jaipur')
# (359, 'Rohit Iyer', 'Male', datetime.date(1991, 6, 8), '9306253131', 'Chennai')
# (360, 'Suresh Reddy', 'Male', datetime.date(1998, 1, 14), '9759543915', 'Jaipur')
# (361, 'Arjun Gupta', 'Male', datetime.date(1999, 3, 18), '9474309458', 'Bengaluru')
# (362, 'Rohit Sharma', 'Male', datetime.date(2000, 4, 23), '9874604749', 'Bengaluru')
# (363, 'Aditya Kumar', 'Male', datetime.date(2008, 2, 19), '9682262713', 'Hyderabad')
# (364, 'Rohit Iyer', 'Male', datetime.date(2002, 8, 30), '9416475636', 'Kolkata')
# (365, 'Rahul Das', 'Male', datetime.date(1999, 4, 7), '9734227594', 'Mumbai')
# (366, 'Nisha Patel', 'Female', datetime.date(2002, 7, 7), '9664091735', 'Mumbai')
# (367, 'Ankit Mehta', 'Male', datetime.date(2002, 10, 9), '9694752176', 'Mumbai')
# (368, 'Sneha Iyer', 'Female', datetime.date(1993, 12, 27), '9607622928', 'Lucknow')
# (369, 'Suresh Verma', 'Male', datetime.date(1999, 6, 20), '9574696750', 'Hyderabad')
# (370, 'Nisha Mehta', 'Female', datetime.date(2006, 7, 16), '9254116051', 'Lucknow')
# (371, 'Isha Gupta', 'Female', datetime.date(2007, 1, 24), '9905532325', 'Jaipur')
# (372, 'Rahul Kumar', 'Male', datetime.date(2009, 4, 17), '9118456292', 'Bengaluru')
# (373, 'Rohit Verma', 'Male', datetime.date(2002, 9, 25), '9396284132', 'Chennai')
# (374, 'Priya Patel', 'Female', datetime.date(1997, 6, 29), '9414508119', 'Kolkata')
# (375, 'Ankit Mehta', 'Male', datetime.date(1995, 7, 10), '9921543583', 'Mumbai')
# (376, 'Ravi Mehta', 'Male', datetime.date(2008, 12, 23), '9732082269', 'Lucknow')
# (377, 'Priya Gupta', 'Female', datetime.date(1996, 12, 22), '9700820188', 'Mumbai')
# (378, 'Vikas Kumar', 'Male', datetime.date(2002, 8, 24), '9217462032', 'Delhi')
# (379, 'Amit Mehta', 'Male', datetime.date(1992, 2, 29), '9893471361', 'Kolkata')
# (380, 'Ravi Mehta', 'Male', datetime.date(2002, 4, 22), '9986864786', 'Lucknow')
# (381, 'Kavya Das', 'Female', datetime.date(2009, 2, 11), '9481873403', 'Indore')
# (382, 'Amit Iyer', 'Male', datetime.date(1990, 11, 11), '9471383012', 'Indore')
# (383, 'Ankit Singh', 'Male', datetime.date(1995, 9, 27), '9535655181', 'Jaipur')
# (384, 'Anjali Sharma', 'Female', datetime.date(2007, 4, 27), '9712446149', 'Chennai')
# (385, 'Arjun Iyer', 'Male', datetime.date(2004, 4, 17), '9754516759', 'Lucknow')
# (386, 'Rohit Das', 'Male', datetime.date(2009, 4, 13), '9926587639', 'Chennai')
# (387, 'Anjali Mehta', 'Female', datetime.date(2008, 12, 13), '9999615077', 'Kolkata')
# (388, 'Suresh Kumar', 'Male', datetime.date(2009, 8, 26), '9660981592', 'Indore')
# (389, 'Anjali Gupta', 'Female', datetime.date(2000, 6, 14), '9205383611', 'Hyderabad')
# (390, 'Rohit Iyer', 'Male', datetime.date(1990, 9, 19), '9184524362', 'Chennai')
# (391, 'Priya Kumar', 'Female', datetime.date(2002, 7, 15), '9849285755', 'Indore')
# (392, 'Pooja Patel', 'Female', datetime.date(2002, 10, 16), '9474362822', 'Pune')
# (393, 'Rohit Singh', 'Male', datetime.date(2005, 12, 15), '9966814811', 'Indore')
# (394, 'Vikas Das', 'Male', datetime.date(1994, 2, 19), '9810576615', 'Delhi')
# (395, 'Priya Das', 'Female', datetime.date(1999, 1, 18), '9512979490', 'Delhi')
# (396, 'Vikas Kumar', 'Male', datetime.date(1999, 6, 9), '9810546608', 'Lucknow')
# (397, 'Kunal Singh', 'Male', datetime.date(1999, 6, 6), '9128079098', 'Indore')
# (398, 'Ravi Gupta', 'Male', datetime.date(2008, 5, 30), '9510614190', 'Lucknow')
# (399, 'Kunal Patel', 'Male', datetime.date(1991, 11, 19), '9182449167', 'Jaipur')
# (400, 'Priya Verma', 'Female', datetime.date(2009, 2, 25), '9845274234', 'Kolkata')
# (401, 'Anjali Patel', 'Female', datetime.date(2000, 11, 4), '9491289553', 'Chennai')
# (402, 'Sneha Kumar', 'Female', datetime.date(1998, 12, 5), '9788046057', 'Lucknow')
# (403, 'Arjun Singh', 'Male', datetime.date(1992, 12, 4), '9469079149', 'Mumbai')
# (404, 'Kunal Gupta', 'Male', datetime.date(1992, 8, 5), '9413957101', 'Lucknow')
# (405, 'Rohit Mehta', 'Male', datetime.date(1994, 4, 3), '9537951326', 'Bengaluru')
# (406, 'Kavya Sharma', 'Female', datetime.date(1996, 1, 23), '9697175441', 'Hyderabad')
# (407, 'Aditya Mehta', 'Male', datetime.date(2000, 5, 10), '9783055822', 'Hyderabad')
# (408, 'Sneha Verma', 'Female', datetime.date(2002, 9, 9), '9583488924', 'Jaipur')
# (409, 'Priya Gupta', 'Female', datetime.date(1996, 6, 30), '9496081538', 'Mumbai')
# (410, 'Arjun Iyer', 'Male', datetime.date(1991, 5, 5), '9262559586', 'Indore')
# (411, 'Priya Verma', 'Female', datetime.date(1995, 12, 7), '9320526045', 'Mumbai')
# (412, 'Neha Gupta', 'Female', datetime.date(1994, 3, 29), '9428739059', 'Mumbai')
# (413, 'Kavya Das', 'Female', datetime.date(1998, 4, 7), '9258376297', 'Delhi')
# (414, 'Vikas Verma', 'Male', datetime.date(2000, 5, 7), '9798253332', 'Hyderabad')
# (415, 'Anjali Singh', 'Female', datetime.date(1990, 12, 28), '9123106761', 'Pune')
# (416, 'Riya Patel', 'Female', datetime.date(2008, 7, 5), '9180920992', 'Indore')
# (417, 'Rahul Patel', 'Male', datetime.date(2004, 7, 11), '9935890707', 'Hyderabad')
# (418, 'Aarti Patel', 'Female', datetime.date(1992, 9, 11), '9877975148', 'Indore')
# (419, 'Amit Das', 'Male', datetime.date(1999, 10, 28), '9308070800', 'Lucknow')
# (420, 'Vikas Gupta', 'Male', datetime.date(2009, 12, 20), '9590050550', 'Mumbai')
# (421, 'Aarti Kumar', 'Female', datetime.date(2003, 2, 15), '9527152639', 'Indore')
# (422, 'Ankit Verma', 'Male', datetime.date(2003, 10, 4), '9223906266', 'Pune')
# (423, 'Anjali Iyer', 'Female', datetime.date(1990, 1, 11), '9189636103', 'Mumbai')
# (424, 'Pooja Iyer', 'Female', datetime.date(2000, 4, 2), '9183251985', 'Kolkata')
# (425, 'Kavya Mehta', 'Female', datetime.date(2008, 9, 30), '9772682325', 'Chennai')
# (426, 'Neha Reddy', 'Female', datetime.date(2002, 10, 18), '9257615927', 'Bengaluru')
# (427, 'Ankit Singh', 'Male', datetime.date(2000, 2, 7), '9256046523', 'Pune')
# (428, 'Sneha Patel', 'Female', datetime.date(1990, 1, 9), '9117127696', 'Lucknow')
# (429, 'Ravi Singh', 'Male', datetime.date(2008, 3, 4), '9903330711', 'Lucknow')
# (430, 'Aarti Verma', 'Female', datetime.date(2000, 12, 9), '9577325668', 'Delhi')
# (431, 'Amit Reddy', 'Male', datetime.date(1995, 5, 14), '9240502056', 'Kolkata')
# (432, 'Rohit Singh', 'Male', datetime.date(1999, 2, 19), '9207465647', 'Mumbai')
# (433, 'Ankit Reddy', 'Male', datetime.date(2001, 4, 19), '9327150313', 'Bengaluru')
# (434, 'Isha Mehta', 'Female', datetime.date(1993, 1, 11), '9874458394', 'Hyderabad')
# (435, 'Neha Das', 'Female', datetime.date(2009, 1, 29), '9593522595', 'Bengaluru')
# (436, 'Riya Singh', 'Female', datetime.date(2006, 11, 27), '9227303245', 'Jaipur')
# (437, 'Ravi Reddy', 'Male', datetime.date(1993, 10, 23), '9696199115', 'Chennai')
# (438, 'Nisha Reddy', 'Female', datetime.date(2009, 3, 31), '9501377028', 'Bengaluru')
# (439, 'Anjali Singh', 'Female', datetime.date(1995, 11, 8), '9370197760', 'Kolkata')
# (440, 'Kavya Mehta', 'Female', datetime.date(2003, 10, 30), '9576996365', 'Delhi')
# (441, 'Aarti Reddy', 'Female', datetime.date(1996, 9, 24), '9235545747', 'Pune')
# (442, 'Ravi Patel', 'Male', datetime.date(1991, 3, 18), '9287118904', 'Kolkata')
# (443, 'Vikas Iyer', 'Male', datetime.date(2004, 10, 5), '9282147188', 'Delhi')
# (444, 'Vikas Verma', 'Male', datetime.date(2000, 11, 12), '9277644681', 'Delhi')
# (445, 'Pooja Mehta', 'Female', datetime.date(1994, 3, 21), '9175890428', 'Indore')
# (446, 'Ravi Verma', 'Male', datetime.date(2007, 10, 30), '9289500973', 'Jaipur')
# (447, 'Sneha Reddy', 'Female', datetime.date(2010, 8, 24), '9662807485', 'Mumbai')
# (448, 'Rohit Verma', 'Male', datetime.date(2009, 3, 12), '9111232126', 'Indore')
# (449, 'Anjali Kumar', 'Female', datetime.date(2003, 4, 2), '9694103336', 'Lucknow')
# (450, 'Arjun Verma', 'Male', datetime.date(1996, 2, 3), '9540715774', 'Bengaluru')
# (451, 'Isha Reddy', 'Female', datetime.date(1996, 1, 9), '9405443281', 'Chennai')
# (452, 'Ankit Mehta', 'Male', datetime.date(1993, 9, 7), '9613380695', 'Delhi')
# (453, 'Sneha Gupta', 'Female', datetime.date(2000, 2, 29), '9166735230', 'Hyderabad')
# (454, 'Aditya Iyer', 'Male', datetime.date(2008, 1, 10), '9939998517', 'Delhi')
# (455, 'Aarti Mehta', 'Female', datetime.date(2000, 12, 12), '9682663700', 'Kolkata')
# (456, 'Rohit Verma', 'Male', datetime.date(2010, 4, 19), '9338007442', 'Delhi')
# (457, 'Ankit Kumar', 'Male', datetime.date(1993, 6, 28), '9268717576', 'Pune')
# (458, 'Aarti Patel', 'Female', datetime.date(2002, 9, 20), '9899517709', 'Hyderabad')
# (459, 'Kavya Gupta', 'Female', datetime.date(2003, 8, 23), '9555910007', 'Mumbai')
# (460, 'Rahul Singh', 'Male', datetime.date(2004, 8, 4), '9170017538', 'Hyderabad')
# (461, 'Aarti Sharma', 'Female', datetime.date(1994, 11, 10), '9137659117', 'Indore')
# (462, 'Anjali Sharma', 'Female', datetime.date(2008, 10, 28), '9626458924', 'Lucknow')
# (463, 'Suresh Reddy', 'Male', datetime.date(2006, 3, 25), '9272804453', 'Lucknow')
# (464, 'Amit Das', 'Male', datetime.date(1998, 11, 26), '9326004019', 'Lucknow')
# (465, 'Aarti Iyer', 'Female', datetime.date(1997, 10, 18), '9112267941', 'Lucknow')
# (466, 'Ravi Sharma', 'Male', datetime.date(2005, 11, 7), '9396995517', 'Kolkata')
# (467, 'Isha Mehta', 'Female', datetime.date(1993, 6, 13), '9822523186', 'Hyderabad')
# (468, 'Kavya Iyer', 'Female', datetime.date(1994, 3, 17), '9906645323', 'Chennai')
# (469, 'Anjali Iyer', 'Female', datetime.date(2007, 9, 4), '9554005862', 'Bengaluru')
# (470, 'Vikas Patel', 'Male', datetime.date(1999, 2, 7), '9394774930', 'Chennai')
# (471, 'Amit Sharma', 'Male', datetime.date(2007, 11, 12), '9271830582', 'Bengaluru')
# (472, 'Riya Das', 'Female', datetime.date(1997, 8, 6), '9114135751', 'Chennai')
# (473, 'Neha Mehta', 'Female', datetime.date(2005, 4, 14), '9405585692', 'Kolkata')
# (474, 'Rahul Das', 'Male', datetime.date(1992, 10, 21), '9964771883', 'Jaipur')
# (475, 'Kunal Reddy', 'Male', datetime.date(1991, 11, 7), '9803865341', 'Jaipur')
# (476, 'Amit Sharma', 'Male', datetime.date(1999, 2, 4), '9931869169', 'Kolkata')
# (477, 'Nisha Mehta', 'Female', datetime.date(1998, 3, 24), '9901249856', 'Kolkata')
# (478, 'Neha Sharma', 'Female', datetime.date(2002, 10, 29), '9710608946', 'Pune')
# (479, 'Rohit Sharma', 'Male', datetime.date(1998, 4, 12), '9526920725', 'Jaipur')
# (480, 'Vikas Iyer', 'Male', datetime.date(2001, 4, 24), '9384644310', 'Mumbai')
# (481, 'Rahul Sharma', 'Male', datetime.date(2008, 11, 9), '9219051266', 'Bengaluru')
# (482, 'Pooja Kumar', 'Female', datetime.date(1993, 7, 19), '9418085297', 'Delhi')
# (483, 'Pooja Mehta', 'Female', datetime.date(1993, 5, 27), '9217802783', 'Hyderabad')
# (484, 'Neha Verma', 'Female', datetime.date(2005, 8, 23), '9933337965', 'Mumbai')
# (485, 'Neha Patel', 'Female', datetime.date(2007, 4, 7), '9816531434', 'Delhi')
# (486, 'Ravi Iyer', 'Male', datetime.date(2010, 1, 4), '9976227344', 'Hyderabad')
# (487, 'Ankit Mehta', 'Male', datetime.date(1990, 4, 3), '9927669764', 'Lucknow')
# (488, 'Riya Patel', 'Female', datetime.date(2006, 9, 13), '9252258057', 'Indore')
# (489, 'Pooja Iyer', 'Female', datetime.date(2002, 6, 14), '9923842174', 'Delhi')
# (490, 'Sneha Sharma', 'Female', datetime.date(2009, 6, 15), '9860141739', 'Indore')
# (491, 'Isha Verma', 'Female', datetime.date(2008, 12, 23), '9198676338', 'Delhi')
# (492, 'Riya Patel', 'Female', datetime.date(1996, 2, 14), '9943079803', 'Bengaluru')
# (493, 'Isha Iyer', 'Female', datetime.date(2006, 3, 8), '9110206342', 'Bengaluru')
# (494, 'Ankit Iyer', 'Male', datetime.date(2008, 12, 9), '9622180226', 'Chennai')
# (495, 'Amit Das', 'Male', datetime.date(1990, 6, 19), '9610375619', 'Lucknow')
# (496, 'Ravi Patel', 'Male', datetime.date(1992, 8, 6), '9765014223', 'Hyderabad')
# (497, 'Isha Patel', 'Female', datetime.date(2004, 10, 8), '9665015920', 'Jaipur')
# (498, 'Sneha Das', 'Female', datetime.date(2009, 10, 10), '9225552466', 'Bengaluru')
# (499, 'Aditya Singh', 'Male', datetime.date(2009, 3, 19), '9321175006', 'Hyderabad')
# (500, 'Ankit Patel', 'Male', datetime.date(1990, 10, 1), '9754027152', 'Mumbai')
# (501, 'Kavya Mehta', 'Female', datetime.date(1991, 8, 9), '9939874526', 'Pune')
# (502, 'Rahul Verma', 'Male', datetime.date(1993, 3, 11), '9657081742', 'Lucknow')
# (503, 'Vikas Patel', 'Male', datetime.date(1991, 11, 15), '9330085348', 'Bengaluru')
# (504, 'Neha Sharma', 'Female', datetime.date(2004, 11, 15), '9578510982', 'Jaipur')
# (505, 'Nisha Patel', 'Female', datetime.date(1991, 12, 3), '9228503053', 'Bengaluru')
# (506, 'Ankit Reddy', 'Male', datetime.date(1997, 3, 12), '9629284736', 'Lucknow')
# (507, 'Neha Mehta', 'Female', datetime.date(1991, 2, 12), '9584819756', 'Jaipur')
# (508, 'Arjun Reddy', 'Male', datetime.date(2000, 4, 29), '9176162929', 'Mumbai')
# (509, 'Arjun Singh', 'Male', datetime.date(1992, 8, 22), '9786200271', 'Pune')
# (510, 'Ankit Patel', 'Male', datetime.date(1992, 10, 29), '9695167582', 'Bengaluru')
# (511, 'Amit Iyer', 'Male', datetime.date(1992, 9, 8), '9434721466', 'Delhi')
# (512, 'Nisha Iyer', 'Female', datetime.date(1995, 7, 12), '9821524815', 'Indore')
# (513, 'Riya Gupta', 'Female', datetime.date(1992, 8, 24), '9545388857', 'Chennai')
# (514, 'Rahul Sharma', 'Male', datetime.date(1996, 10, 18), '9462656547', 'Mumbai')
# (515, 'Isha Iyer', 'Female', datetime.date(2010, 2, 4), '9365463103', 'Chennai')
# (516, 'Riya Verma', 'Female', datetime.date(1997, 8, 9), '9145517619', 'Jaipur')
# (517, 'Nisha Kumar', 'Female', datetime.date(2006, 4, 4), '9389880413', 'Jaipur')
# (518, 'Neha Singh', 'Female', datetime.date(2001, 10, 11), '9568737521', 'Chennai')
# (519, 'Ravi Kumar', 'Male', datetime.date(1995, 4, 23), '9829468398', 'Bengaluru')
# (520, 'Nisha Mehta', 'Female', datetime.date(1996, 9, 21), '9272290227', 'Bengaluru')
# (521, 'Vikas Gupta', 'Male', datetime.date(1992, 7, 3), '9875649234', 'Chennai')
# (522, 'Aarti Sharma', 'Female', datetime.date(2007, 10, 18), '9272225096', 'Lucknow')
# (523, 'Rahul Patel', 'Male', datetime.date(1993, 4, 10), '9856867745', 'Lucknow')
# (524, 'Neha Kumar', 'Female', datetime.date(2000, 1, 22), '9928761110', 'Indore')
# (525, 'Arjun Gupta', 'Male', datetime.date(2003, 3, 9), '9825586866', 'Indore')
# (526, 'Aarti Mehta', 'Female', datetime.date(1995, 8, 2), '9468403397', 'Bengaluru')
# (527, 'Aarti Kumar', 'Female', datetime.date(1993, 12, 11), '9110777059', 'Mumbai')
# (528, 'Riya Patel', 'Female', datetime.date(1990, 6, 29), '9808434261', 'Chennai')
# (529, 'Nisha Patel', 'Female', datetime.date(1997, 8, 7), '9307005510', 'Delhi')
# (530, 'Rohit Singh', 'Male', datetime.date(2009, 9, 4), '9718800381', 'Mumbai')
# (531, 'Riya Gupta', 'Female', datetime.date(2003, 1, 9), '9615605840', 'Pune')
# (532, 'Anjali Singh', 'Female', datetime.date(2001, 4, 4), '9966044449', 'Hyderabad')
# (533, 'Isha Patel', 'Female', datetime.date(2003, 12, 14), '9511586086', 'Lucknow')
# (534, 'Amit Das', 'Male', datetime.date(1997, 10, 14), '9732294924', 'Hyderabad')
# (535, 'Aarti Iyer', 'Female', datetime.date(2000, 12, 9), '9173441095', 'Pune')
# (536, 'Sneha Verma', 'Female', datetime.date(1993, 8, 16), '9953542158', 'Chennai')
# (537, 'Kunal Iyer', 'Male', datetime.date(2003, 1, 26), '9661383910', 'Hyderabad')
# (538, 'Priya Mehta', 'Female', datetime.date(2000, 11, 11), '9703660010', 'Kolkata')
# (539, 'Vikas Kumar', 'Male', datetime.date(2001, 3, 20), '9187370695', 'Hyderabad')
# (540, 'Rohit Singh', 'Male', datetime.date(2006, 4, 21), '9859355018', 'Kolkata')
# (541, 'Kunal Kumar', 'Male', datetime.date(2000, 4, 7), '9548949857', 'Delhi')
# (542, 'Priya Reddy', 'Female', datetime.date(2005, 3, 4), '9442166642', 'Delhi')
# (543, 'Arjun Kumar', 'Male', datetime.date(1994, 5, 27), '9178512579', 'Pune')
# (544, 'Isha Reddy', 'Female', datetime.date(2001, 4, 2), '9687487446', 'Delhi')
# (545, 'Rohit Kumar', 'Male', datetime.date(1995, 9, 5), '9481951080', 'Hyderabad')
# (546, 'Ankit Patel', 'Male', datetime.date(1994, 7, 7), '9146473554', 'Mumbai')
# (547, 'Kunal Verma', 'Male', datetime.date(2001, 12, 21), '9793356601', 'Indore')
# (548, 'Priya Kumar', 'Female', datetime.date(1999, 3, 25), '9499649532', 'Kolkata')
# (549, 'Priya Das', 'Female', datetime.date(1992, 9, 8), '9280649307', 'Hyderabad')
# (550, 'Isha Iyer', 'Female', datetime.date(2005, 4, 5), '9670377959', 'Indore')
# (551, 'Kunal Mehta', 'Male', datetime.date(1997, 10, 23), '9636919084', 'Chennai')
# (552, 'Kunal Reddy', 'Male', datetime.date(2005, 9, 11), '9927398025', 'Chennai')
# (553, 'Rahul Verma', 'Male', datetime.date(1990, 7, 24), '9543414806', 'Pune')
# (554, 'Rahul Kumar', 'Male', datetime.date(1993, 2, 12), '9321003715', 'Bengaluru')
# (555, 'Priya Verma', 'Female', datetime.date(2003, 2, 9), '9819724235', 'Kolkata')
# (556, 'Ankit Singh', 'Male', datetime.date(2008, 3, 10), '9162417696', 'Indore')
# (557, 'Priya Reddy', 'Female', datetime.date(2010, 7, 11), '9700308814', 'Jaipur')
# (558, 'Aditya Gupta', 'Male', datetime.date(2006, 4, 21), '9378557347', 'Kolkata')
# (559, 'Amit Mehta', 'Male', datetime.date(1994, 10, 13), '9881706870', 'Pune')
# (560, 'Arjun Sharma', 'Male', datetime.date(2004, 8, 10), '9632507109', 'Delhi')
# (561, 'Isha Mehta', 'Female', datetime.date(2005, 7, 8), '9266471268', 'Indore')
# (562, 'Isha Iyer', 'Female', datetime.date(2005, 9, 8), '9799990296', 'Chennai')
# (563, 'Riya Kumar', 'Female', datetime.date(2002, 7, 11), '9864228804', 'Mumbai')
# (564, 'Suresh Kumar', 'Male', datetime.date(1994, 8, 8), '9571745308', 'Pune')
# (565, 'Rahul Sharma', 'Male', datetime.date(1993, 5, 26), '9803733249', 'Kolkata')
# (566, 'Arjun Sharma', 'Male', datetime.date(2005, 6, 4), '9167379479', 'Bengaluru')
# (567, 'Nisha Kumar', 'Female', datetime.date(1992, 5, 7), '9631639315', 'Kolkata')
# (568, 'Sneha Gupta', 'Female', datetime.date(1993, 12, 14), '9681682644', 'Kolkata')
# (569, 'Aditya Gupta', 'Male', datetime.date(1998, 1, 3), '9366177558', 'Pune')
# (570, 'Ravi Gupta', 'Male', datetime.date(2003, 4, 22), '9662965603', 'Pune')
# (571, 'Kunal Sharma', 'Male', datetime.date(2000, 5, 13), '9992019532', 'Mumbai')
# (572, 'Kunal Das', 'Male', datetime.date(1990, 1, 31), '9746444714', 'Chennai')
# (573, 'Priya Sharma', 'Female', datetime.date(1997, 2, 12), '9530241830', 'Delhi')
# (574, 'Aarti Iyer', 'Female', datetime.date(2010, 7, 26), '9964796065', 'Kolkata')
# (575, 'Suresh Verma', 'Male', datetime.date(2004, 8, 25), '9224899369', 'Lucknow')
# (576, 'Riya Patel', 'Female', datetime.date(2003, 3, 21), '9350501124', 'Pune')
# (577, 'Ankit Verma', 'Male', datetime.date(2003, 7, 16), '9630664762', 'Indore')
# (578, 'Ravi Patel', 'Male', datetime.date(2008, 4, 1), '9829133871', 'Indore')
# (579, 'Vikas Patel', 'Male', datetime.date(2000, 7, 29), '9468407455', 'Jaipur')
# (580, 'Arjun Gupta', 'Male', datetime.date(1996, 6, 15), '9871699289', 'Kolkata')
# (581, 'Aarti Gupta', 'Female', datetime.date(2010, 11, 6), '9385915183', 'Pune')
# (582, 'Kunal Iyer', 'Male', datetime.date(2004, 3, 3), '9642721450', 'Jaipur')
# (583, 'Aditya Kumar', 'Male', datetime.date(2007, 3, 30), '9825721426', 'Hyderabad')
# (584, 'Vikas Kumar', 'Male', datetime.date(2002, 1, 21), '9898718170', 'Indore')
# (585, 'Ankit Das', 'Male', datetime.date(2005, 1, 10), '9112453870', 'Jaipur')
# ...
# (807, 'Neha Iyer', 'Female', datetime.date(1992, 12, 3), '9818425582', 'Delhi')
# (808, 'Nisha Iyer', 'Female', datetime.date(2007, 11, 22), '9186899739', 'Indore')
# (809, 'Arjun Mehta', 'Male', datetime.date(1997, 7, 1), '9714326081', 'Jaipur')
# (810, 'Kunal Patel', 'Male', datetime.date(1991, 11, 2), '9550768295', 'Bengaluru')
# (811, 'Vikas Mehta', 'Male', datetime.date(1991, 3, 27), '9184471277', 'Hyderabad')
# (812, 'Ravi Verma', 'Male', datetime.date(2008, 10, 9), '9371211992', 'Jaipur')
# (813, 'Ankit Sharma', 'Male', datetime.date(2006, 3, 22), '9889715081', 'Delhi')
# (814, 'Ravi Sharma', 'Male', datetime.date(2002, 6, 16), '9973457069', 'Lucknow')
# (815, 'Aarti Sharma', 'Female', datetime.date(1994, 6, 22), '9472760171', 'Pune')
# (816, 'Ankit Das', 'Male', datetime.date(2000, 7, 1), '9516890471', 'Lucknow')
# (817, 'Nisha Reddy', 'Female', datetime.date(2005, 8, 26), '9311041054', 'Indore')
# (818, 'Aarti Sharma', 'Female', datetime.date(2010, 9, 8), '9335789587', 'Mumbai')
# (819, 'Ravi Kumar', 'Male', datetime.date(2007, 2, 28), '9497831014', 'Mumbai')
# (820, 'Rahul Kumar', 'Male', datetime.date(2002, 11, 14), '9268194415', 'Pune')
# (821, 'Isha Iyer', 'Female', datetime.date(1996, 8, 4), '9923405369', 'Lucknow')
# (822, 'Sneha Sharma', 'Female', datetime.date(2007, 6, 18), '9256578259', 'Kolkata')
# (823, 'Nisha Kumar', 'Female', datetime.date(1998, 10, 8), '9301629837', 'Pune')
# (824, 'Ravi Sharma', 'Male', datetime.date(1994, 2, 12), '9833914062', 'Chennai')
# (825, 'Priya Kumar', 'Female', datetime.date(2006, 4, 27), '9114228118', 'Indore')
# (826, 'Sneha Verma', 'Female', datetime.date(2005, 4, 7), '9492137912', 'Indore')
# (827, 'Rahul Patel', 'Male', datetime.date(2006, 11, 2), '9339150386', 'Kolkata')
# (828, 'Aarti Verma', 'Female', datetime.date(2005, 12, 15), '9117992238', 'Pune')
# (829, 'Aarti Iyer', 'Female', datetime.date(1998, 6, 30), '9759113006', 'Hyderabad')
# (830, 'Aditya Gupta', 'Male', datetime.date(2010, 1, 21), '9106473614', 'Lucknow')
# (831, 'Aditya Reddy', 'Male', datetime.date(2010, 4, 19), '9676564261', 'Delhi')
# (832, 'Suresh Sharma', 'Male', datetime.date(2005, 11, 28), '9448581670', 'Hyderabad')
# (833, 'Neha Das', 'Female', datetime.date(1998, 1, 2), '9410747989', 'Kolkata')
# (834, 'Priya Gupta', 'Female', datetime.date(1995, 4, 27), '9218581057', 'Kolkata')
# (835, 'Neha Mehta', 'Female', datetime.date(1993, 8, 13), '9165310002', 'Kolkata')
# (836, 'Arjun Patel', 'Male', datetime.date(1998, 5, 25), '9795566841', 'Kolkata')
# (837, 'Isha Kumar', 'Female', datetime.date(1992, 2, 1), '9670818332', 'Kolkata')
# (838, 'Arjun Kumar', 'Male', datetime.date(1997, 12, 8), '9782900679', 'Bengaluru')
# (839, 'Rahul Kumar', 'Male', datetime.date(1995, 11, 9), '9744068418', 'Delhi')
# (840, 'Ravi Gupta', 'Male', datetime.date(1997, 1, 30), '9306048585', 'Delhi')
# (841, 'Aditya Reddy', 'Male', datetime.date(1991, 12, 1), '9412651032', 'Kolkata')
# (842, 'Rohit Sharma', 'Male', datetime.date(1993, 1, 29), '9644918494', 'Indore')
# (843, 'Vikas Gupta', 'Male', datetime.date(2009, 10, 29), '9601218756', 'Hyderabad')
# (844, 'Neha Verma', 'Female', datetime.date(2000, 5, 27), '9273055912', 'Lucknow')
# (845, 'Arjun Kumar', 'Male', datetime.date(2006, 7, 18), '9722719539', 'Chennai')
# (846, 'Isha Verma', 'Female', datetime.date(2002, 5, 4), '9646472438', 'Kolkata')
# (847, 'Ravi Gupta', 'Male', datetime.date(1995, 4, 27), '9718460228', 'Pune')
# (848, 'Suresh Das', 'Male', datetime.date(1994, 8, 5), '9363747610', 'Mumbai')
# (849, 'Vikas Gupta', 'Male', datetime.date(2001, 7, 2), '9209163314', 'Lucknow')
# (850, 'Nisha Verma', 'Female', datetime.date(2005, 6, 14), '9723213961', 'Pune')
# (851, 'Nisha Reddy', 'Female', datetime.date(1990, 3, 11), '9416732820', 'Chennai')
# (852, 'Rohit Mehta', 'Male', datetime.date(2007, 3, 6), '9473406159', 'Hyderabad')
# (853, 'Rahul Gupta', 'Male', datetime.date(2006, 5, 19), '9877287830', 'Lucknow')
# (854, 'Rohit Singh', 'Male', datetime.date(1996, 7, 18), '9602211172', 'Bengaluru')
# (855, 'Priya Kumar', 'Female', datetime.date(2000, 8, 11), '9737020614', 'Pune')
# (856, 'Neha Verma', 'Female', datetime.date(1992, 8, 16), '9786913745', 'Lucknow')
# (857, 'Arjun Das', 'Male', datetime.date(1995, 7, 27), '9852562149', 'Mumbai')
# (858, 'Ankit Kumar', 'Male', datetime.date(1998, 3, 18), '9778292077', 'Indore')
# (859, 'Isha Das', 'Female', datetime.date(1995, 2, 20), '9116933808', 'Delhi')
# (860, 'Kavya Verma', 'Female', datetime.date(1997, 11, 3), '9489693487', 'Lucknow')
# (861, 'Amit Mehta', 'Male', datetime.date(2009, 12, 19), '9285543745', 'Mumbai')
# (862, 'Ravi Mehta', 'Male', datetime.date(1998, 5, 15), '9851301841', 'Delhi')
# (863, 'Ankit Patel', 'Male', datetime.date(2009, 9, 15), '9264334635', 'Bengaluru')
# (864, 'Ravi Sharma', 'Male', datetime.date(2003, 5, 16), '9489862446', 'Pune')
# (865, 'Priya Reddy', 'Female', datetime.date(2003, 6, 6), '9662979469', 'Jaipur')
# (866, 'Sneha Singh', 'Female', datetime.date(2010, 8, 18), '9658381575', 'Kolkata')
# (867, 'Sneha Iyer', 'Female', datetime.date(2004, 10, 9), '9678404355', 'Kolkata')
# (868, 'Ankit Reddy', 'Male', datetime.date(2010, 6, 5), '9937928449', 'Delhi')
# (869, 'Pooja Sharma', 'Female', datetime.date(2010, 9, 1), '9643621166', 'Bengaluru')
# (870, 'Neha Patel', 'Female', datetime.date(2007, 1, 11), '9620471951', 'Indore')
# (871, 'Priya Gupta', 'Female', datetime.date(1991, 8, 8), '9742636422', 'Chennai')
# (872, 'Kunal Patel', 'Male', datetime.date(1991, 5, 13), '9142595260', 'Chennai')
# (873, 'Kunal Kumar', 'Male', datetime.date(1998, 1, 11), '9388935486', 'Mumbai')
# (874, 'Arjun Das', 'Male', datetime.date(2008, 11, 21), '9155222016', 'Indore')
# (875, 'Amit Das', 'Male', datetime.date(1994, 12, 12), '9453130864', 'Lucknow')
# (876, 'Suresh Sharma', 'Male', datetime.date(2006, 12, 4), '9978948162', 'Delhi')
# (877, 'Ankit Gupta', 'Male', datetime.date(2007, 11, 7), '9905330980', 'Mumbai')
# (878, 'Aarti Kumar', 'Female', datetime.date(1992, 12, 13), '9908228256', 'Hyderabad')
# (879, 'Sneha Sharma', 'Female', datetime.date(1996, 12, 23), '9487086951', 'Jaipur')
# (880, 'Kunal Patel', 'Male', datetime.date(1990, 5, 16), '9769491983', 'Jaipur')
# (881, 'Ankit Verma', 'Male', datetime.date(1996, 6, 30), '9964813350', 'Indore')
# (882, 'Nisha Gupta', 'Female', datetime.date(2008, 3, 5), '9604449637', 'Delhi')
# (883, 'Pooja Das', 'Female', datetime.date(1994, 1, 3), '9226445312', 'Bengaluru')
# (884, 'Pooja Iyer', 'Female', datetime.date(2008, 4, 15), '9919316534', 'Lucknow')
# (885, 'Rohit Reddy', 'Male', datetime.date(2001, 3, 22), '9578115707', 'Indore')
# (886, 'Riya Mehta', 'Female', datetime.date(1995, 11, 6), '9162803065', 'Pune')
# (887, 'Suresh Iyer', 'Male', datetime.date(2000, 9, 21), '9350280304', 'Lucknow')
# (888, 'Aditya Gupta', 'Male', datetime.date(1999, 8, 12), '9385962743', 'Hyderabad')
# (889, 'Ravi Iyer', 'Male', datetime.date(2003, 5, 26), '9865596752', 'Delhi')
# (890, 'Arjun Das', 'Male', datetime.date(2004, 6, 22), '9429911117', 'Jaipur')
# (891, 'Rahul Verma', 'Male', datetime.date(1992, 6, 13), '9708692763', 'Chennai')
# (892, 'Suresh Das', 'Male', datetime.date(2007, 10, 23), '9581786067', 'Pune')
# (893, 'Rohit Das', 'Male', datetime.date(2010, 11, 5), '9961719387', 'Lucknow')
# (894, 'Kunal Kumar', 'Male', datetime.date(2002, 8, 5), '9966057335', 'Hyderabad')
# (895, 'Arjun Das', 'Male', datetime.date(1991, 9, 17), '9784617707', 'Bengaluru')
# (896, 'Nisha Singh', 'Female', datetime.date(2004, 4, 29), '9996132998', 'Jaipur')
# (897, 'Nisha Kumar', 'Female', datetime.date(1997, 4, 8), '9971888878', 'Mumbai')
# (898, 'Anjali Iyer', 'Female', datetime.date(1996, 10, 18), '9723899790', 'Hyderabad')
# (899, 'Ravi Das', 'Male', datetime.date(1990, 9, 15), '9667312037', 'Indore')
# (900, 'Ankit Patel', 'Male', datetime.date(2002, 10, 9), '9768846825', 'Kolkata')
# (901, 'Rohit Das', 'Male', datetime.date(2004, 7, 2), '9763858513', 'Bengaluru')
# (902, 'Rohit Sharma', 'Male', datetime.date(1992, 7, 18), '9861257218', 'Hyderabad')
# (903, 'Ankit Iyer', 'Male', datetime.date(1999, 8, 16), '9517782774', 'Lucknow')
# (904, 'Vikas Patel', 'Male', datetime.date(2003, 4, 9), '9718880272', 'Delhi')
# (905, 'Pooja Kumar', 'Female', datetime.date(1991, 12, 9), '9505577095', 'Indore')
# (906, 'Pooja Sharma', 'Female', datetime.date(2008, 5, 23), '9439859820', 'Lucknow')
# (907, 'Nisha Verma', 'Female', datetime.date(1998, 7, 5), '9996767201', 'Hyderabad')
# (908, 'Suresh Mehta', 'Male', datetime.date(2008, 7, 29), '9887678549', 'Jaipur')
# (909, 'Nisha Reddy', 'Female', datetime.date(2009, 12, 17), '9512521771', 'Indore')
# (910, 'Riya Kumar', 'Female', datetime.date(2004, 12, 18), '9289828756', 'Jaipur')
# (911, 'Riya Gupta', 'Female', datetime.date(2001, 6, 20), '9571118054', 'Jaipur')
# (912, 'Aarti Das', 'Female', datetime.date(1996, 5, 28), '9171492654', 'Jaipur')
# (913, 'Arjun Reddy', 'Male', datetime.date(1991, 11, 25), '9686120657', 'Indore')
# (914, 'Kunal Reddy', 'Male', datetime.date(1994, 3, 13), '9347007674', 'Hyderabad')
# (915, 'Rohit Reddy', 'Male', datetime.date(2005, 12, 5), '9995970904', 'Jaipur')
# (916, 'Arjun Mehta', 'Male', datetime.date(2010, 9, 20), '9127703496', 'Kolkata')
# (917, 'Arjun Kumar', 'Male', datetime.date(1996, 6, 20), '9924181731', 'Hyderabad')
# (918, 'Pooja Das', 'Female', datetime.date(2002, 9, 2), '9803274484', 'Kolkata')
# (919, 'Isha Verma', 'Female', datetime.date(1995, 12, 16), '9710037247', 'Chennai')
# (920, 'Pooja Das', 'Female', datetime.date(2009, 7, 13), '9664085411', 'Hyderabad')
# (921, 'Rahul Das', 'Male', datetime.date(1994, 1, 24), '9505712256', 'Delhi')
# (922, 'Isha Mehta', 'Female', datetime.date(2002, 3, 26), '9691879531', 'Delhi')
# (923, 'Aditya Sharma', 'Male', datetime.date(1990, 8, 7), '9647345904', 'Lucknow')
# (924, 'Rohit Das', 'Male', datetime.date(2006, 7, 24), '9366216583', 'Hyderabad')
# (925, 'Vikas Singh', 'Male', datetime.date(2002, 12, 23), '9633598757', 'Bengaluru')
# (926, 'Ravi Kumar', 'Male', datetime.date(1995, 8, 26), '9897684548', 'Delhi')
# (927, 'Suresh Gupta', 'Male', datetime.date(2007, 6, 29), '9609976914', 'Indore')
# (928, 'Priya Das', 'Female', datetime.date(2003, 2, 9), '9202745519', 'Pune')
# (929, 'Pooja Iyer', 'Female', datetime.date(2010, 9, 20), '9811689495', 'Chennai')
# (930, 'Ankit Verma', 'Male', datetime.date(1999, 3, 14), '9915592876', 'Hyderabad')
# (931, 'Aditya Singh', 'Male', datetime.date(2002, 11, 1), '9757167421', 'Hyderabad')
# (932, 'Aarti Sharma', 'Female', datetime.date(2009, 6, 15), '9453635916', 'Pune')
# (933, 'Suresh Reddy', 'Male', datetime.date(2009, 8, 1), '9865195603', 'Delhi')
# (934, 'Ravi Iyer', 'Male', datetime.date(1994, 5, 29), '9402217289', 'Indore')
# (935, 'Kunal Das', 'Male', datetime.date(2002, 12, 9), '9872674377', 'Delhi')
# (936, 'Rohit Iyer', 'Male', datetime.date(2002, 9, 5), '9900424028', 'Hyderabad')
# (937, 'Kunal Kumar', 'Male', datetime.date(1995, 1, 30), '9923732031', 'Kolkata')
# (938, 'Riya Reddy', 'Female', datetime.date(2007, 4, 22), '9768097266', 'Kolkata')
# (939, 'Isha Iyer', 'Female', datetime.date(1993, 10, 10), '9339916098', 'Jaipur')
# (940, 'Kunal Gupta', 'Male', datetime.date(2010, 1, 26), '9893299783', 'Kolkata')
# (941, 'Amit Mehta', 'Male', datetime.date(1995, 6, 18), '9655552149', 'Delhi')
# (942, 'Kunal Iyer', 'Male', datetime.date(2005, 5, 27), '9746321311', 'Pune')
# (943, 'Riya Mehta', 'Female', datetime.date(2007, 8, 18), '9491179237', 'Indore')
# (944, 'Aarti Kumar', 'Female', datetime.date(2007, 11, 12), '9469269156', 'Indore')
# (945, 'Aarti Iyer', 'Female', datetime.date(2004, 4, 19), '9289217443', 'Jaipur')
# (946, 'Ravi Kumar', 'Male', datetime.date(1995, 9, 26), '9406252556', 'Kolkata')
# (947, 'Vikas Sharma', 'Male', datetime.date(1992, 12, 3), '9250208870', 'Kolkata')
# (948, 'Nisha Gupta', 'Female', datetime.date(1990, 10, 5), '9314459773', 'Hyderabad')
# (949, 'Rohit Das', 'Male', datetime.date(2010, 11, 23), '9426539507', 'Indore')
# (950, 'Rohit Kumar', 'Male', datetime.date(1999, 7, 28), '9356618459', 'Pune')
# (951, 'Sneha Singh', 'Female', datetime.date(2006, 4, 26), '9444282994', 'Lucknow')
# (952, 'Suresh Iyer', 'Male', datetime.date(1999, 10, 5), '9270827932', 'Kolkata')
# (953, 'Ravi Reddy', 'Male', datetime.date(1996, 5, 14), '9808211515', 'Jaipur')
# (954, 'Amit Mehta', 'Male', datetime.date(1994, 9, 2), '9602697795', 'Hyderabad')
# (955, 'Anjali Mehta', 'Female', datetime.date(2000, 9, 10), '9924202666', 'Chennai')
# (956, 'Ravi Singh', 'Male', datetime.date(1994, 3, 10), '9788806579', 'Mumbai')
# (957, 'Nisha Singh', 'Female', datetime.date(2004, 11, 22), '9103626042', 'Delhi')
# (958, 'Aditya Verma', 'Male', datetime.date(1994, 7, 8), '9478346105', 'Hyderabad')
# (959, 'Aditya Iyer', 'Male', datetime.date(1990, 5, 6), '9658900654', 'Lucknow')
# (960, 'Nisha Kumar', 'Female', datetime.date(2001, 8, 2), '9941154795', 'Chennai')
# (961, 'Priya Verma', 'Female', datetime.date(2002, 9, 25), '9848225594', 'Pune')
# (962, 'Rahul Singh', 'Male', datetime.date(2008, 10, 1), '9334100930', 'Chennai')
# (963, 'Suresh Verma', 'Male', datetime.date(2004, 1, 18), '9463815197', 'Bengaluru')
# (964, 'Nisha Sharma', 'Female', datetime.date(2006, 11, 10), '9165888160', 'Mumbai')
# (965, 'Aditya Iyer', 'Male', datetime.date(1995, 10, 29), '9690467630', 'Mumbai')
# (966, 'Kavya Gupta', 'Female', datetime.date(2006, 4, 27), '9567095669', 'Mumbai')
# (967, 'Nisha Iyer', 'Female', datetime.date(2010, 7, 10), '9420854142', 'Lucknow')
# (968, 'Kavya Das', 'Female', datetime.date(2003, 7, 12), '9804821669', 'Indore')
# (969, 'Ankit Reddy', 'Male', datetime.date(2000, 10, 11), '9472351844', 'Bengaluru')
# (970, 'Amit Reddy', 'Male', datetime.date(2006, 5, 24), '9978580859', 'Jaipur')
# (971, 'Aarti Reddy', 'Female', datetime.date(1992, 7, 11), '9968039175', 'Bengaluru')
# (972, 'Isha Das', 'Female', datetime.date(1993, 5, 2), '9351857102', 'Jaipur')
# (973, 'Aarti Gupta', 'Female', datetime.date(2010, 3, 13), '9228610694', 'Hyderabad')
# (974, 'Aarti Iyer', 'Female', datetime.date(2000, 8, 16), '9181223429', 'Jaipur')
# (975, 'Aditya Verma', 'Male', datetime.date(1994, 2, 10), '9444118781', 'Hyderabad')
# (976, 'Ankit Das', 'Male', datetime.date(2002, 12, 26), '9307844600', 'Chennai')
# (977, 'Aarti Sharma', 'Female', datetime.date(2003, 10, 20), '9783647462', 'Kolkata')
# (978, 'Ankit Iyer', 'Male', datetime.date(2001, 5, 19), '9150672000', 'Lucknow')
# (979, 'Kunal Iyer', 'Male', datetime.date(2010, 12, 11), '9982922995', 'Hyderabad')
# (980, 'Amit Patel', 'Male', datetime.date(1993, 10, 27), '9774090772', 'Delhi')
# (981, 'Isha Patel', 'Female', datetime.date(2008, 4, 21), '9933527546', 'Indore')
# (982, 'Ravi Iyer', 'Male', datetime.date(2006, 6, 3), '9959448935', 'Kolkata')
# (983, 'Rahul Singh', 'Male', datetime.date(2005, 8, 29), '9479986266', 'Bengaluru')
# (984, 'Riya Singh', 'Female', datetime.date(1991, 8, 21), '9573877931', 'Mumbai')
# (985, 'Kavya Reddy', 'Female', datetime.date(2003, 3, 29), '9899745409', 'Kolkata')
# (986, 'Kavya Singh', 'Female', datetime.date(1997, 11, 22), '9205859557', 'Indore')
# (987, 'Ankit Kumar', 'Male', datetime.date(1990, 5, 30), '9532013121', 'Delhi')
# (988, 'Aditya Reddy', 'Male', datetime.date(1992, 10, 12), '9672640794', 'Pune')
# (989, 'Nisha Sharma', 'Female', datetime.date(1998, 11, 15), '9440365712', 'Lucknow')
# (990, 'Rahul Das', 'Male', datetime.date(2006, 7, 16), '9579469150', 'Mumbai')
# (991, 'Aditya Mehta', 'Male', datetime.date(1998, 2, 26), '9848362931', 'Kolkata')
# (992, 'Kavya Kumar', 'Female', datetime.date(2007, 8, 29), '9547929104', 'Bengaluru')
# (993, 'Suresh Gupta', 'Male', datetime.date(1990, 9, 2), '9548641721', 'Pune')
# (994, 'Suresh Das', 'Male', datetime.date(1998, 9, 23), '9364404646', 'Jaipur')
# (995, 'Anjali Das', 'Female', datetime.date(1998, 2, 21), '9509867867', 'Bengaluru')
# (996, 'Sneha Singh', 'Female', datetime.date(2001, 10, 10), '9141769629', 'Kolkata')
# (997, 'Priya Singh', 'Female', datetime.date(2000, 8, 27), '9913217444', 'Hyderabad')
# (998, 'Isha Gupta', 'Female', datetime.date(1993, 2, 15), '9700415770', 'Kolkata')
# (999, 'Arjun Mehta', 'Male', datetime.date(1990, 11, 22), '9382217429', 'Kolkata')
# (1000, 'Pooja Mehta', 'Female', datetime.date(2001, 4, 15), '9988155057', 'Chennai')

# %%
import mysql.connector
import pandas as pd

# connect to mysql
db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="schema_demo"
)

# read 100 records into dataframe
df = pd.read_sql("select * from student limit 1000", db)

# save as csv
df.to_csv("student_1000_records.csv", index=False)

print("CSV file created: student_100_records.csv")
# Out:
# CSV file created: student_100_records.csv
# /tmp/ipython-input-3128620220.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from student limit 1000", db)

# %%
# !apt-get install graphviz
# !pip install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (0.21)

# %%
from graphviz import Digraph

erd = Digraph("ERD", format="png")
erd.attr(rankdir="LR", bgcolor="#EFE6FF")

# =======================
# CONCEPTUAL ERD
# =======================
with erd.subgraph(name="cluster_conceptual") as c:
    c.attr(label="Conceptual ERD", style="filled", color="#D6C8FF")
    c.node("Student_C", "STUDENT", shape="rectangle", style="filled", fillcolor="#6EC6C6")

# =======================
# LOGICAL ERD
# =======================
with erd.subgraph(name="cluster_logical") as l:
    l.attr(label="Logical ERD", style="filled", color="#D6C8FF")

    l.node(
        "Student_L",
        "STUDENT",
        shape="rectangle",
        style="filled",
        fillcolor="#6EC6C6"
    )

    # Attributes
    l.node("student_id", "student_id", shape="ellipse")
    l.node("name", "name", shape="ellipse")
    l.node("gender", "gender", shape="ellipse")
    l.node("dob", "dob", shape="ellipse")
    l.node("phone", "phone", shape="ellipse")
    l.node("city", "city", shape="ellipse")
    # Connections
    l.edge("Student_L", "student_id")
    l.edge("Student_L", "name")
    l.edge("Student_L", "gender")
    l.edge("Student_L", "dob")
    l.edge("Student_L", "phone")
    l.edge("Student_L", "city")

# =======================
# PHYSICAL ERD
# =======================
with erd.subgraph(name="cluster_physical") as p:
    p.attr(label="Physical ERD", style="filled", color="#D6C8FF")

    p.node(
        "Student_P",
        '''<

            student
            student_id INT PRIMARY KEY
            name VARCHAR(100) NOT NULL
            gender VARCHAR(10)
            dob DATE
            phone VARCHAR(15) UNIQUE
            city VARCHAR(50)

        >'''
    )

erd
